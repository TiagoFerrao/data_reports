# %% [markdown]
# <h1>Índice<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Setup-Inicial-e-pré-tratamento" data-toc-modified-id="Setup-Inicial-e-pré-tratamento-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Setup Inicial e pré-tratamento</a></span></li><li><span><a href="#Tratamento-do-Questionário-dos-Incubados" data-toc-modified-id="Tratamento-do-Questionário-dos-Incubados-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Tratamento do Questionário dos Incubados</a></span><ul class="toc-item"><li><span><a href="#Ajustar/alterar-nomes-das-colunas." data-toc-modified-id="Ajustar/alterar-nomes-das-colunas.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Ajustar/alterar nomes das colunas.</a></span><ul class="toc-item"><li><span><a href="#Colunas-do-sector-de-actividade" data-toc-modified-id="Colunas-do-sector-de-actividade-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Colunas do sector de actividade</a></span></li><li><span><a href="#Colunas-da-transferência-de-conhecimento" data-toc-modified-id="Colunas-da-transferência-de-conhecimento-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Colunas da transferência de conhecimento</a></span></li></ul></li><li><span><a href="#Colunas-das-ferramentas-transferência-de-conhecimento" data-toc-modified-id="Colunas-das-ferramentas-transferência-de-conhecimento-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Colunas das ferramentas transferência de conhecimento</a></span></li><li><span><a href="#Colunas-das-dificuldades-(c_dif_#)" data-toc-modified-id="Colunas-das-dificuldades-(c_dif_#)-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Colunas das dificuldades (c_dif_#)</a></span></li><li><span><a href="#Colunas-do-valor-adicionado-pela-incubdor-(c_inc_value_#)" data-toc-modified-id="Colunas-do-valor-adicionado-pela-incubdor-(c_inc_value_#)-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Colunas do valor adicionado pela incubdor (c_inc_value_#)</a></span></li><li><span><a href="#Colunas-dos-resultados-derivados-da-incubadora-(c_inc_result_#)" data-toc-modified-id="Colunas-dos-resultados-derivados-da-incubadora-(c_inc_result_#)-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Colunas dos resultados derivados da incubadora (c_inc_result_#)</a></span></li><li><span><a href="#Simplificação-das-Variáveis-Categóricas" data-toc-modified-id="Simplificação-das-Variáveis-Categóricas-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Simplificação das Variáveis Categóricas</a></span><ul class="toc-item"><li><span><a href="#Idade-dos-incubados-p_age" data-toc-modified-id="Idade-dos-incubados-p_age-2.6.1"><span class="toc-item-num">2.6.1&nbsp;&nbsp;</span>Idade dos incubados p_age</a></span></li><li><span><a href="#Genero-p_gender" data-toc-modified-id="Genero-p_gender-2.6.2"><span class="toc-item-num">2.6.2&nbsp;&nbsp;</span>Genero p_gender</a></span></li><li><span><a href="#Grau-de-Escolaridade-p_literacy" data-toc-modified-id="Grau-de-Escolaridade-p_literacy-2.6.3"><span class="toc-item-num">2.6.3&nbsp;&nbsp;</span>Grau de Escolaridade p_literacy</a></span></li><li><span><a href="#Incubadora-inc_name" data-toc-modified-id="Incubadora-inc_name-2.6.4"><span class="toc-item-num">2.6.4&nbsp;&nbsp;</span>Incubadora inc_name</a></span></li><li><span><a href="#Nomes-da-empresa-incubada" data-toc-modified-id="Nomes-da-empresa-incubada-2.6.5"><span class="toc-item-num">2.6.5&nbsp;&nbsp;</span>Nomes da empresa incubada</a></span></li><li><span><a href="#Localizaçao-da-empresa-incubada-(sede-legal?)" data-toc-modified-id="Localizaçao-da-empresa-incubada-(sede-legal?)-2.6.6"><span class="toc-item-num">2.6.6&nbsp;&nbsp;</span>Localizaçao da empresa incubada (sede legal?)</a></span></li><li><span><a href="#Idade-da-empresa-incubada-c_age" data-toc-modified-id="Idade-da-empresa-incubada-c_age-2.6.7"><span class="toc-item-num">2.6.7&nbsp;&nbsp;</span>Idade da empresa incubada c_age</a></span></li><li><span><a href="#Numero-de-empregados-na-empresa" data-toc-modified-id="Numero-de-empregados-na-empresa-2.6.8"><span class="toc-item-num">2.6.8&nbsp;&nbsp;</span>Numero de empregados na empresa</a></span></li><li><span><a href="#Tempo-de-residencia-da-empresa-na-incubadora-c_resident_time(years)" data-toc-modified-id="Tempo-de-residencia-da-empresa-na-incubadora-c_resident_time(years)-2.6.9"><span class="toc-item-num">2.6.9&nbsp;&nbsp;</span>Tempo de residencia da empresa na incubadora c_resident_time(years)</a></span></li><li><span><a href="#Atualização-do-tipo-das-variáveis-para-categoricas-ou-boolean" data-toc-modified-id="Atualização-do-tipo-das-variáveis-para-categoricas-ou-boolean-2.6.10"><span class="toc-item-num">2.6.10&nbsp;&nbsp;</span>Atualização do tipo das variáveis para categoricas ou boolean</a></span></li><li><span><a href="#Eliminação-de-colunas:" data-toc-modified-id="Eliminação-de-colunas:-2.6.11"><span class="toc-item-num">2.6.11&nbsp;&nbsp;</span>Eliminação de colunas:</a></span></li></ul></li><li><span><a href="#Incubadoras" data-toc-modified-id="Incubadoras-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Incubadoras</a></span><ul class="toc-item"><li><span><a href="#Ajustar/alterar-nomes-das-colunas." data-toc-modified-id="Ajustar/alterar-nomes-das-colunas.-2.7.1"><span class="toc-item-num">2.7.1&nbsp;&nbsp;</span>Ajustar/alterar nomes das colunas.</a></span></li><li><span><a href="#Análise-Inicial-e-Mapa-de-Valores-Omissos" data-toc-modified-id="Análise-Inicial-e-Mapa-de-Valores-Omissos-2.7.2"><span class="toc-item-num">2.7.2&nbsp;&nbsp;</span>Análise Inicial e Mapa de Valores Omissos</a></span></li><li><span><a href="#Colunas-dos-Vínculos" data-toc-modified-id="Colunas-dos-Vínculos-2.7.3"><span class="toc-item-num">2.7.3&nbsp;&nbsp;</span>Colunas dos Vínculos</a></span></li><li><span><a href="#Colunas-Das-Fases-de-Incubação" data-toc-modified-id="Colunas-Das-Fases-de-Incubação-2.7.4"><span class="toc-item-num">2.7.4&nbsp;&nbsp;</span>Colunas Das Fases de Incubação</a></span></li><li><span><a href="#Colunas-da-Selecção-de-Empresas" data-toc-modified-id="Colunas-da-Selecção-de-Empresas-2.7.5"><span class="toc-item-num">2.7.5&nbsp;&nbsp;</span>Colunas da Selecção de Empresas</a></span></li><li><span><a href="#Colunas-das-CARÊNCIAS-das-empresas-incubads-(handicaps)" data-toc-modified-id="Colunas-das-CARÊNCIAS-das-empresas-incubads-(handicaps)-2.7.6"><span class="toc-item-num">2.7.6&nbsp;&nbsp;</span>Colunas das CARÊNCIAS das empresas incubads (handicaps)</a></span></li><li><span><a href="#Colunas-do-'Conhecimento-de-Gestão'" data-toc-modified-id="Colunas-do-'Conhecimento-de-Gestão'-2.7.7"><span class="toc-item-num">2.7.7&nbsp;&nbsp;</span>Colunas do 'Conhecimento de Gestão'</a></span></li><li><span><a href="#Colunas-das-ferramentas-de-transferencia-de-conhecimento" data-toc-modified-id="Colunas-das-ferramentas-de-transferencia-de-conhecimento-2.7.8"><span class="toc-item-num">2.7.8&nbsp;&nbsp;</span>Colunas das ferramentas de transferencia de conhecimento</a></span></li><li><span><a href="#Simplificação-das-restantes-colunas" data-toc-modified-id="Simplificação-das-restantes-colunas-2.7.9"><span class="toc-item-num">2.7.9&nbsp;&nbsp;</span>Simplificação das restantes colunas</a></span></li><li><span><a href="#Mudança-do-tipo-de-coluna" data-toc-modified-id="Mudança-do-tipo-de-coluna-2.7.10"><span class="toc-item-num">2.7.10&nbsp;&nbsp;</span>Mudança do tipo de coluna</a></span></li></ul></li></ul></li><li><span><a href="#Exportação-da-base-de-dados-para-CSV-com-Dtypes" data-toc-modified-id="Exportação-da-base-de-dados-para-CSV-com-Dtypes-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Exportação da base de dados para CSV com Dtypes</a></span><ul class="toc-item"><li><span><a href="#Incubados" data-toc-modified-id="Incubados-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Incubados</a></span></li><li><span><a href="#Incubadoras" data-toc-modified-id="Incubadoras-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Incubadoras</a></span></li></ul></li></ul></div>

# %% [markdown]
# # <center> EMPREENDEDORISMO EM ANGOLA
# # <center> PARTE 1: LIMPEZA E TRATAMENTO DE DADOS

# %% [markdown]
# ## Setup Inicial e pré-tratamento
# Foram recebido 3 ficheiros (2 excel e 1 doc). Foram criadas cópias dos 2 ficheiros e efetuadas as seguintes alterações:
#
# |Novo File|survey_incubados.xls   |survey_incubadoras.xls|
# |--------:|:-----------------------|:-----------------------|
# |ficheiro original|Questionário para Incubados Base de dados (1)|Questionário para gestores aprovado Base de Dados.xlsx|
# |#1|"Sector de Actividade do Negócio"-> *unmerge* e criaçao de **activity_sector**_1,2,3..5|"Vínculos Institucionais da Incubadora"-> *unmerge* e criação de **vinculo**_1,2|
# |#2|"Quais as principais dificuldades da empresa durante o processo de incubação" -> *unmerge* e criaçao de **dificulty**_1,2,3..6|"Qual é o estágio de incubação?" -> *unmerge* e criaçao de **stage_1**,2,3..6|
# |#3|"Quais os conhecimentos gestão transferidos pela incubadora".-> *unmerge* e criaçao de **knowledge_transfered**_1,2,3..7|"Como é feita a selecção das empresas que serão incubadas?"-> *unmerge* e criaçao de **select_by_projects, select_by_ideas, select_by_others**; dado o reduzido numero de respostas os valores foram substituidos por sim/nao com base nas respostas disponiveis|
# |#4|"Quais as ferramentas e práticas são utilizadas pela incubadora para a transferência de conhecimento de gestão a empresa?" -> *unmerge* e criaçao de **knw_transfer_tool**_1,2..4|"Quais são as principais carências das empresas incubadas durante o processo de incubação?" -> *unmerge* e criaçao de **handicap_entrepeneur_knw,handicap_technical_knw,handicap_management_knw, handicap_management_exp**; considerando o numero reduzido de observações substituiriam se os valores por sim/nao |
# |#5|"O que mais lhe ajudou a incubadora" -> *unmerge* e criaçao de **inc_value**_1,2..4|"Quanto ao Conhecimento de gestão"-> *unmerge* e criação de **manag_knw**_1,2..6|
# |#6|"Qual foi à vantagem de ter permanecido na incubadora?"-> *unmerge* e criaçao de **inc_result**_1,2..4|"Quais as ferramentas e práticas utilizadas para transferencia de conhecimento"-> *unmerge* e criação de **knw_transfer_tools**_1,2..6|
# |#7|eliminaçao da linha que distingue os dados do empreendedor das empresas (passa a constar do nome da variável)|idem|
# |#8|criação da coluna "id" que recebe o numero sequencial de cada linha de forma a manter essa informação|idem|
# |#9||correçao dos valores "nome da incubadora" de modo a coincidir com os valores utilizados no survey_incubados.xls|

# %%
#import modules
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.options.display.max_columns = 100 #increase the limit of columns seen

# %% [markdown]
# A importação dois surveys foi bem sucedida como se verifica abaixo:
# Os dois questionários serão guardados nas variáveis `incubados` e `incubadoras`.

# %% [markdown]
# ## Tratamento do Questionário dos Incubados

# %%
#leitura do ficheiro "survey_incubados.xls"
incubados = pd.read_excel("./data_input/survey_incubados.xls", index_col=0, true_values=["Sim"],false_values=["Não"])

# %% [markdown]
# ### Ajustar/alterar nomes das colunas.
# Nesta fase vamos simplificar o nome das colunas de modo a criar uma variável explicativa do racional da pergunta mas mantendo a estrutura tabelar, de forma a facilitar o tratamento estatistico.
#
# As colunas têm os nomes das questões do questionário. Para o objectivo de criar estatistiscas descritivas e gráficos, cada perguntar representa uma variável a caracterizar pelo que será conveniente utilizar nomes mais curtos para facilitar a manipulação, plotagem e análise.

# %%
#nomes  das colunas atuais
incubados.columns
# Out:
# Index(['Nome ', 'Grupo Etário', 'Sexo', 'Nível de Escolaridade',
#        'Nome da Incubadora', 'Nome da Empresa',
#        'Localização do Empreendimento ', 'Número de Funcionários',
#        'activity_sector_1', 'activity_sector_2', 'activity_sector_3',
#        'activity_sector_4', 'activity_sector_5', 'Tempo em Actividade',
#        'A sua empresa está certificada pelo INAPEM',
#        'Como está classificada a sua Empresa?',
#        'Há quanto tempo a empresa está incubada',
#        'Em que etapa do processo de incubação ela se encontra',
#        'Como classifica o grau e a frequência de comunicação e interacção entre incubadora e empresa?',
#        'dificulty_1', 'dificulty_2', 'dificulty_3', 'dificulty_4',
#        'dificulty_5', 'dificulty_6', 'knowledge_transfered_1',
#        'knowledge_transfered_2', 'knowledge_transfered_3',
#        'knowledge_transfered_4', 'knowledge_transfered_5',
#        'knowledge_transfered_6', 'knowledge_transfered_7',
#        'knw_transfer_tool_1', 'knw_transfer_tool_2', 'knw_transfer_tool_3',
#        'knw_transfer_tool_4', 'inc_value_1', 'inc_value_2', 'inc_value_3',
#        'inc_value_4', 'inc_value_5', 'inc_value_6', 'inc_value_7',
#        'inc_result_1', 'inc_result_2', 'inc_result_3', 'inc_result_4',
#        'inc_result_5', 'A incubadora tem ligações com as Universidades',
#        'A incubadora continua a apoiar após a sua saída da incubadora?'],
#       dtype='object')

# %% [markdown]
# Dado que existem dois tipos de perguntas (sobre o empreender e sobre a empresa incubada) utilizaremos o prefixo p_ (person) e c_ (corporation) respectivamente para as perguntas sobre os empreendedores e sobre as empresas incubadas.

# %%
# Novos nomes sugeridos
incubados_column_names = {'Nome ':'p_name', 
                          'Grupo Etário':'p_age',
                          'Sexo':'p_gender',
                          'Nível de Escolaridade':'p_literacy',
                          'Nome da Incubadora':'inc_name', 
                          'Nome da Empresa':'c_name',
                          'Localização do Empreendimento ':'c_location', 
                          'Número de Funcionários':'c_employees',
                          'activity_sector_1':'c_sector_1',
                          'activity_sector_2':'c_sector_2', 
                          'activity_sector_3':'c_sector_3',
                          'activity_sector_4':'c_sector_4',
                          'activity_sector_5':'c_sector_5', 
                          'Tempo em Actividade':'c_age',
                          'A sua empresa está certificada pelo INAPEM':'c_inapem?',
                          'Como está classificada a sua Empresa?':'c_size',
                          'Há quanto tempo a empresa está incubada':'c_resident_time',
                          'Em que etapa do processo de incubação ela se encontra':'c_stage',
                          'Como classifica o grau e a frequência de comunicação e interacção entre incubadora e empresa?':'c_linkto_inc',
                          'dificulty_1':'c_dif_1', 
                          'dificulty_2':'c_dif_2', 
                          'dificulty_3':'c_dif_3', 
                          'dificulty_4':'c_dif_4',
                          'dificulty_5':'c_dif_5', 
                          'dificulty_6':'c_dif_6', 
                          'knowledge_transfered_1':'c_knw_trans_1',
                          'knowledge_transfered_2':'c_knw_trans_2', 
                          'knowledge_transfered_3':'c_knw_trans_3',
                          'knowledge_transfered_4':'c_knw_trans_4',
                          'knowledge_transfered_5':'c_knw_trans_5',
                          'knowledge_transfered_6':'c_knw_trans_6',
                          'knowledge_transfered_7':'c_knw_trans_7',
                          'knw_transfer_tool_1':'c_knw_trans_tool_1',
                          'knw_transfer_tool_2':'c_knw_trans_tool_2',
                          'knw_transfer_tool_3':'c_knw_trans_tool_3',
                          'knw_transfer_tool_4':'c_knw_trans_tool_4', 
                          'inc_value_1':'c_inc_value_1', 
                          'inc_value_2':'c_inc_value_2', 
                          'inc_value_3':'c_inc_value_3',
                          'inc_value_4':'c_inc_value_4',
                          'inc_value_5':'c_inc_value_5',
                          'inc_value_6':'c_inc_value_6',
                          'inc_value_7':'c_inc_value_7',
                          'inc_result_1':'c_inc_result_1',
                          'inc_result_2':'c_inc_result_2',
                          'inc_result_3':'c_inc_result_3',
                          'inc_result_4':'c_inc_result_4',
                          'inc_result_5':'c_inc_result_5',
                          'A incubadora tem ligações com as Universidades':'c_inc_link_uni?',
                          'A incubadora continua a apoiar após a sua saída da incubadora?':'c_inc_pos_support?'}

# %%
incubados.rename(columns = incubados_column_names, inplace=True)

# %%
### b) Valores omissos

# %%
plt.figure(figsize=(15,5))
sns.heatmap(incubados.notnull(), linewidths=1, cbar=False)
# Out:
# <AxesSubplot:ylabel='ID'>

# %% [markdown]
# Como se verifica  no heatmap acima, o dataset tem vários valores omissos (a preto), correspondentes a:
# - linhas vazias
# - colunas vazias e,
# - colunas com poucos valores correspondentes às colunas de escolhar múltipla

# %%
# em primeiro lugar vamos eliminar linhas e colunas completamente vazias:
incubados.dropna(axis=0,how="all", inplace=True) #delete all empty rows
incubados.dropna(axis=1,how="all", inplace=True) #delete all empty columns

# %% [markdown]
# Após a remoçao de linhas e colunas vazias, permanecem as colunas de escolha multipla:
#    - Sector de atividade
#    - Dificuldades sentidas
#    - Tipo de conhecimento transmitido pela incubadora
#    - Ferramentas de transmissao de conhecimento
#    - Valor adicionado pela incubadora
#    - Resultados obtidos
#
# A estratégia para preecher este valores será a de considerar que os respondentes só assinalam as opções que são verdade para o seu caso (True) e as não assinaladas serão preenchidas com o valor (False).
# Algumas destas colunas foram pré preenchidas com com valores Sim/Não e transformadas em True/False no momento da importação. Os nomes das colunas também poderão ser alterados para refletir a opção assinalada.  Faremos esta analise, coluna a coluna.

# %% [markdown]
# #### Colunas do sector de actividade
# Vamos criar uma variável categorica binomial que vai ser True caso o incubado tenha respondido esse sector de atividade e False em caso  contrario.

# %%
sector_columns = ['c_sector_1','c_sector_2','c_sector_3','c_sector_4','c_sector_5']
incubados[sector_columns]
# Out:
#                                            c_sector_1  \
# ID
# 1   (O)- Outras Actividades de Serviços Colectivos...
# 2   (K)- Actividades Imobiliárias, Alugueres e Ser...
# 3   (H)- Alojamento e Restauração (Restaurantes e ...
# 4                                       (M)- Educação
# 5                                       (M)- Educação
# ..                                                ...
# 60  (O)- Outras Actividades de Serviços Colectivos...
# 61  (O)- Outras Actividades de Serviços Colectivos...
# 62  (O)- Outras Actividades de Serviços Colectivos...
# 63  (K)- Actividades Imobiliárias, Alugueres e Ser...
# 64  (K)- Actividades Imobiliárias, Alugueres e Ser...
#
#                                            c_sector_2 c_sector_3 c_sector_4  \
# ID
# 1                                                 NaN        NaN        NaN
# 2                                                 NaN        NaN        NaN
# 3                                                 NaN        NaN        NaN
# 4   (O)- Outras Actividades de Serviços Colectivos...        NaN        NaN
# 5                                                 NaN        NaN        NaN
# ..                                                ...        ...        ...
# 60                                                NaN        NaN        NaN
# 61                                                NaN        NaN        NaN
# 62                                                NaN        NaN        NaN
# 63  (O)- Outras Actividades de Serviços Colectivos...        NaN        NaN
# 64                                                NaN        NaN        NaN
#
#    c_sector_5
# ID
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# ..        ...
# 60        NaN
# 61        NaN
# 62        NaN
# 63        NaN
# 64        NaN
#
# [64 rows x 5 columns]

# %%
incubados[sector_columns].notnull().sum()
# Out:
# c_sector_1    63
# c_sector_2    10
# c_sector_3     3
# c_sector_4     2
# c_sector_5     1
# dtype: int64

# %% [markdown]
# Vemos que o numero de registos diminui ao longo das colunas indicando, provavelmente, atividades primárias, secundárias e terciárias.

# %%
incubados[sector_columns[0]].unique() #valores uniques respondidos na primeira coluna
# Out:
# array(['(O)- Outras Actividades de Serviços Colectivos, Social e Pessoais',
#        '(K)- Actividades Imobiliárias, Alugueres e Serviços Prestados às Empresas',
#        '(H)- Alojamento e Restauração (Restaurantes e Similares)',
#        '(M)- Educação',
#        '(A)- Agricultura, Produção Animal e Silvicultura',
#        '(C)- Indústrias Extractivas', '(F)- Construção e obras públicas',
#        '(J)- Actividades Financeiras',
#        '(E)- Produção e distribuição de Electricidade, Gás e de Água',
#        '(G)- Comércio por Grosso e a Retalho; Reparação de Veículos Automóvel, Motociclos e de Bens de Uso Pessoal e Doméstico',
#        nan, '(I)- Transportes, Armazenagem e Comunicações',
#        '(N)- Saúde e Acção Social'], dtype=object)

# %%
#com base nos valores das respostas, podemos construir a lista de todas as atividades que foram respondidas pelo menos uma vez
criteria_list = [
    '(O)- Outras Actividades de Serviços Colectivos, Social e Pessoais',
    '(K)- Actividades Imobiliárias, Alugueres e Serviços Prestados às Empresas',
    '(H)- Alojamento e Restauração (Restaurantes e Similares)',
    '(M)- Educação',
    '(A)- Agricultura, Produção Animal e Silvicultura',
    '(C)- Indústrias Extractivas', 
    '(F)- Construção e obras públicas',
    '(J)- Actividades Financeiras',
    '(E)- Produção e distribuição de Electricidade, Gás e de Água',
    '(G)- Comércio por Grosso e a Retalho; Reparação de Veículos Automóvel, Motociclos e de Bens de Uso Pessoal e Doméstico',
    '(I)- Transportes, Armazenagem e Comunicações',
    '(N)- Saúde e Acção Social']

# %%
subset = incubados.iloc[:,8:13] # slice of the dataframe to convert to a new set of columns

# %%
def transpose_values(criteria_list,subset):
    results = pd.DataFrame(columns= criteria_list) # empty dataframe that will contain the results
    for criteria in criteria_list:
        if pd.isnull(criteria):
            pass
        else:
            match = subset == criteria
            results[criteria] = match.any(axis=1)
    return results

# %%
results = transpose_values(criteria_list,subset)
results.sum(axis=1).value_counts()
# Out:
# 1    53
# 2     7
# 0     1
# 3     1
# 4     1
# 5     1
# dtype: int64

# %% [markdown]
# A maior parte dos incubados pertence apenas a um sector, 7 pertencem a dois 1 pertence a 5 sectores.

# %%
#Eliminamos as antigas colunas que já não são necessárias e adicionamos os resultados 
incubados_updated = pd.concat([incubados,results], axis=1)
incubados_updated.drop(sector_columns, axis=1, inplace=True)

# %% [markdown]
# Vamos agora simplificar os nomeas das colunas dos sectores de atividade, substituindo apenas pela letra de acordo com a tabela:
#
# |Código|Atividade Económica|
# |:----:|:------------------|
# |(O)| Outras Actividades de Serviços Colectivos, Social e Pessoais|
# |(K)| Actividades Imobiliárias, Alugueres e Serviços Prestados às Empresas|
# |(H)| Alojamento e Restauração (Restaurantes e Similares|
# |(M)| Educação|
# |(A)| Agricultura, Produção Animal e Silvicultura|
# |(C)| Indústrias Extractivas|
# |(F)| Construção e obras públicas|
# |(J)| Actividades Financeiras|
# |(E)| Produção e distribuição de Electricidade, Gás e de Água|
# |(G)| Comércio por Grosso e a Retalho; Reparação de Veículos Automóvel, Motociclos e de Bens de Uso Pessoal e Doméstico|
# |(I)| Transportes, Armazenagem e Comunicações|
# |(N)| Saúde e Acção Social|

# %%
#Substituição da descrição longa pela letra correspondente
activity_columns = incubados_updated.iloc[:,37:].columns
activity_columns
# Out:
# Index(['(O)- Outras Actividades de Serviços Colectivos, Social e Pessoais',
#        '(K)- Actividades Imobiliárias, Alugueres e Serviços Prestados às Empresas',
#        '(H)- Alojamento e Restauração (Restaurantes e Similares)',
#        '(M)- Educação', '(A)- Agricultura, Produção Animal e Silvicultura',
#        '(C)- Indústrias Extractivas', '(F)- Construção e obras públicas',
#        '(J)- Actividades Financeiras',
#        '(E)- Produção e distribuição de Electricidade, Gás e de Água',
#        '(G)- Comércio por Grosso e a Retalho; Reparação de Veículos Automóvel, Motociclos e de Bens de Uso Pessoal e Doméstico',
#        '(I)- Transportes, Armazenagem e Comunicações',
#        '(N)- Saúde e Acção Social'],
#       dtype='object')

# %%
clean_columns = activity_columns.str.split(")").str[0].str.replace("(","", regex=False)

# %%
clean_columns = ["c_act_sector_"+item for item in clean_columns]

# %%
incubados_updated.rename(columns=dict(zip(activity_columns,clean_columns)), inplace=True)

# %%
plt.figure(figsize=(15,5))
sns.heatmap(incubados_updated.notnull(), linewidths=1, cbar=False)
# Out:
# <AxesSubplot:ylabel='ID'>

# %% [markdown]
# #### Colunas da transferência de conhecimento
# Vamos repetir os passos das colunas do sector de atividade
# 1. Isolar as colunas respectivas (subset)
# 2. Identificar os valores unicos (criteria_list)
# 3. Criar uma coluna por cada valor unico
# 4. Preencher com True/False (sim/nao) com base nos valores do subset
# 5. Eliminar subset

# %%
incubados_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64 entries, 1 to 64
# Data columns (total 49 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   p_name              57 non-null     object
#  1   p_age               64 non-null     object
#  2   p_gender            64 non-null     object
#  3   p_literacy          64 non-null     object
#  4   inc_name            64 non-null     object
#  5   c_name              55 non-null     object
#  6   c_location          63 non-null     object
#  7   c_employees         64 non-null     object
#  8   c_age               63 non-null     object
#  9   c_inapem?           63 non-null     object
#  10  c_size              64 non-null     object
#  11  c_resident_time     64 non-null     object
#  12  c_stage             64 non-null     object
#  13  c_linkto_inc        64 non-null     object
#  14  c_dif_1             56 non-null     object
#  15  c_dif_2             20 non-null     object
#  16  c_dif_3             6 non-null      object
#  17  c_dif_4             1 non-null      object
#  18  c_knw_trans_1       56 non-null     object
#  19  c_knw_trans_2       21 non-null     object
#  20  c_knw_trans_3       7 non-null      object
#  21  c_knw_trans_4       7 non-null      object
#  22  c_knw_trans_5       1 non-null      object
#  23  c_knw_trans_6       1 non-null      object
#  24  c_knw_trans_tool_1  58 non-null     object
#  25  c_knw_trans_tool_2  19 non-null     object
#  26  c_knw_trans_tool_3  2 non-null      object
#  27  c_knw_trans_tool_4  1 non-null      object
#  28  c_inc_value_1       57 non-null     object
#  29  c_inc_value_2       17 non-null     object
#  30  c_inc_value_3       6 non-null      object
#  31  c_inc_value_4       2 non-null      object
#  32  c_inc_result_1      60 non-null     object
#  33  c_inc_result_2      28 non-null     object
#  34  c_inc_result_3      10 non-null     object
#  35  c_inc_link_uni?     59 non-null     object
#  36  c_inc_pos_support?  49 non-null     object
#  37  c_act_sector_O      64 non-null     bool
#  38  c_act_sector_K      64 non-null     bool
#  39  c_act_sector_H      64 non-null     bool
#  40  c_act_sector_M      64 non-null     bool
#  41  c_act_sector_A      64 non-null     bool
#  42  c_act_sector_C      64 non-null     bool
#  43  c_act_sector_F      64 non-null     bool
#  44  c_act_sector_J      64 non-null     bool
#  45  c_act_sector_E      64 non-null     bool
#  46  c_act_sector_G      64 non-null     bool
#  47  c_act_sector_I      64 non-null     bool
#  48  c_act_sector_N      64 non-null     bool
# dtypes: bool(12), object(37)
# memory usage: 19.8+ KB

# %%
#da lista de colunas vemos que sao as 18-23, 6 
subset2 = incubados_updated.iloc[:,18:24]
subset2
# Out:
#                              c_knw_trans_1  \
# ID
# 1                                Marketing
# 2                         Recursos Humanos
# 3   Comercialização de produtos e serviços
# 4                         Recursos Humanos
# 5                                Marketing
# ..                                     ...
# 60                        Empreendedorismo
# 61                        Recursos Humanos
# 62                               Marketing
# 63                        Empreendedorismo
# 64                        Empreendedorismo
#
#                              c_knw_trans_2      c_knw_trans_3  \
# ID
# 1                         Empreendedorismo                NaN
# 2                                Marketing                NaN
# 3                         Empreendedorismo                NaN
# 4                                      NaN                NaN
# 5                         Empreendedorismo                NaN
# ..                                     ...                ...
# 60                                     NaN                NaN
# 61                        Empreendedorismo                NaN
# 62  Comercialização de produtos e serviços  Gestão Financeira
# 63                                     NaN                NaN
# 64                                     NaN                NaN
#
#        c_knw_trans_4 c_knw_trans_5 c_knw_trans_6
# ID
# 1                NaN           NaN           NaN
# 2                NaN           NaN           NaN
# 3                NaN           NaN           NaN
# 4                NaN           NaN           NaN
# 5                NaN           NaN           NaN
# ..               ...           ...           ...
# 60               NaN           NaN           NaN
# 61               NaN           NaN           NaN
# 62  Empreendedorismo           NaN           NaN
# 63               NaN           NaN           NaN
# 64               NaN           NaN           NaN
#
# [64 rows x 6 columns]

# %%
subset2.notnull().sum()
# Out:
# c_knw_trans_1    56
# c_knw_trans_2    21
# c_knw_trans_3     7
# c_knw_trans_4     7
# c_knw_trans_5     1
# c_knw_trans_6     1
# dtype: int64

# %% [markdown]
# A maior parte dos registos estao nas colunas 1 e 2

# %%
criteria_list2 =  subset2['c_knw_trans_1'].unique() #nao existem valores adicionais(unicos) nas outras colunas
criteria_list2
# Out:
# array(['Marketing', 'Recursos Humanos',
#        'Comercialização de produtos e serviços', 'Assistência jurídica',
#        nan, 'Empreendedorismo', 'Gestão Estratégica', 'Gestão Financeira'],
#       dtype=object)

# %%
criteria_list2 =['Marketing', 'Recursos Humanos',
       'Comercialização de produtos e serviços', 'Assistência jurídica', 'Empreendedorismo', 'Gestão Estratégica', 'Gestão Financeira']

# %%
results2 = transpose_values(criteria_list2,subset2)
results2
# Out:
#     Marketing  Recursos Humanos  Comercialização de produtos e serviços  \
# ID
# 1        True             False                                   False
# 2        True              True                                   False
# 3       False             False                                    True
# 4       False              True                                   False
# 5        True             False                                   False
# ..        ...               ...                                     ...
# 60      False             False                                   False
# 61      False              True                                   False
# 62       True             False                                    True
# 63      False             False                                   False
# 64      False             False                                   False
#
#     Assistência jurídica  Empreendedorismo  Gestão Estratégica  \
# ID
# 1                  False              True               False
# 2                  False             False               False
# 3                  False              True               False
# 4                  False             False               False
# 5                  False              True               False
# ..                   ...               ...                 ...
# 60                 False              True               False
# 61                 False              True               False
# 62                 False              True               False
# 63                 False              True               False
# 64                 False              True               False
#
#     Gestão Financeira
# ID
# 1               False
# 2               False
# 3               False
# 4               False
# 5               False
# ..                ...
# 60              False
# 61              False
# 62               True
# 63              False
# 64              False
#
# [64 rows x 7 columns]

# %%
short = ['mrkt',
 'hr',
 'sales',
 'legal',
 'entrpre',
 'strt',
 'finc']

# %%
clean_columns2 = ["c_knw_trans_"+item for item in short]

clean_columns2 = dict(zip(criteria_list2,clean_columns2))

# %%
clean_columns2
# Out:
# {'Marketing': 'c_knw_trans_mrkt',
#  'Recursos Humanos': 'c_knw_trans_hr',
#  'Comercialização de produtos e serviços': 'c_knw_trans_sales',
#  'Assistência jurídica': 'c_knw_trans_legal',
#  'Empreendedorismo': 'c_knw_trans_entrpre',
#  'Gestão Estratégica': 'c_knw_trans_strt',
#  'Gestão Financeira': 'c_knw_trans_finc'}

# %%
results2.rename(columns = clean_columns2, inplace=True)

# %%
#vamos juntar os resultados ao nosso dataset e eliminar as colunas antigas deste subset
incubados_updated2 = pd.concat([incubados_updated, results2], axis=1 )

# %%
incubados_updated2.drop(subset2.columns, axis=1,inplace=True)

# %%
plt.figure(figsize=(15,5))
sns.heatmap(incubados_updated2.notnull(), linewidths=1, cbar=False)
# Out:
# <AxesSubplot:ylabel='ID'>

# %% [markdown]
# No heatmap de dados omissos, já só são visiveis 4 grupos de variáveis, as dificuldades, as ferramentas de transferenci de conhecimento,o valor adicionado pela incubador e valor adicionado pela incubadora.

# %% [markdown]
# ### Colunas das ferramentas transferência de conhecimento
# Vamos repetir os passos das colunas do sector de atividade
# 1. Isolar as colunas respectivas (subset3)
# 2. Identificar os valores unicos (criteria_list3)
# 3. Criar uma coluna por cada valor unico
# 4. Preencher com True/False (sim/nao) com base nos valores do subset
# 5. Eliminar subset3 da base de dados atualizada

# %%
#da lista de colunas acima identificam-se as colinas 18:21
subset3 = incubados_updated2.iloc[:,18:22]
subset3
# Out:
#     c_knw_trans_tool_1  c_knw_trans_tool_2 c_knw_trans_tool_3  \
# ID
# 1             Manuais   Formação e cursos                 NaN
# 2             Manuais                  NaN                NaN
# 3   Formação e cursos                  NaN                NaN
# 4   Formação e cursos                  NaN                NaN
# 5             Manuais              Fóruns                 NaN
# ..                 ...                 ...                ...
# 60            Manuais                  NaN                NaN
# 61            Manuais                  NaN                NaN
# 62            Manuais   Formação e cursos             Fóruns
# 63            Manuais                  NaN                NaN
# 64            Manuais   Formação e cursos                 NaN
#
#    c_knw_trans_tool_4
# ID
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# ..                ...
# 60                NaN
# 61                NaN
# 62      Benchmarking
# 63                NaN
# 64                NaN
#
# [64 rows x 4 columns]

# %%
subset3.notnull().sum()
# Out:
# c_knw_trans_tool_1    58
# c_knw_trans_tool_2    19
# c_knw_trans_tool_3     2
# c_knw_trans_tool_4     1
# dtype: int64

# %%
subset3['c_knw_trans_tool_1'].unique()
# Out:
# array(['Manuais ', 'Formação e cursos ', nan, 'Fóruns '], dtype=object)

# %%
subset3['c_knw_trans_tool_2'].unique()
# Out:
# array(['Formação e cursos ', nan, 'Fóruns ', 'Benchmarking '],
#       dtype=object)

# %%
criteria_list3 = ['Manuais ', 'Formação e cursos ', 'Benchmarking ', 'Fóruns ']

# %%
results3 = transpose_values(criteria_list3,subset3)
results3.sum(axis=0)
# Out:
# Manuais               26
# Formação e cursos     46
# Benchmarking           3
# Fóruns                 5
# dtype: int64

# %%
results3
# Out:
#     Manuais   Formação e cursos   Benchmarking   Fóruns
# ID
# 1       True                True          False    False
# 2       True               False          False    False
# 3      False                True          False    False
# 4      False                True          False    False
# 5       True               False          False     True
# ..       ...                 ...            ...      ...
# 60      True               False          False    False
# 61      True               False          False    False
# 62      True                True           True     True
# 63      True               False          False    False
# 64      True                True          False    False
#
# [64 rows x 4 columns]

# %%
#renomear as colunas para a convençao utilizada
results3.columns
# Out:
# Index(['Manuais ', 'Formação e cursos ', 'Benchmarking ', 'Fóruns '], dtype='object')

# %%
short3 = ['manuais', 'training', 'benchmarking', 'forums']
clean_columns3 = ["c_knw_trans_tool_"+item for item in short3]

clean_columns3 = dict(zip(criteria_list3,clean_columns3))
results3.rename(columns = clean_columns3, inplace=True)

# %%
results3
# Out:
#     c_knw_trans_tool_manuais  c_knw_trans_tool_training  \
# ID
# 1                       True                       True
# 2                       True                      False
# 3                      False                       True
# 4                      False                       True
# 5                       True                      False
# ..                       ...                        ...
# 60                      True                      False
# 61                      True                      False
# 62                      True                       True
# 63                      True                      False
# 64                      True                       True
#
#     c_knw_trans_tool_benchmarking  c_knw_trans_tool_forums
# ID
# 1                           False                    False
# 2                           False                    False
# 3                           False                    False
# 4                           False                    False
# 5                           False                     True
# ..                            ...                      ...
# 60                          False                    False
# 61                          False                    False
# 62                           True                     True
# 63                          False                    False
# 64                          False                    False
#
# [64 rows x 4 columns]

# %%
#juntar o resultado ao dataset original e apagar as colunas anteriores
incubados_updated3 = pd.concat([incubados_updated2, results3], axis=1 )
incubados_updated3.drop(subset3.columns, axis=1,inplace=True)

# %%
plt.figure(figsize=(15,5))
sns.heatmap(incubados_updated3.notnull(), linewidths=1, cbar=False)
# Out:
# <AxesSubplot:ylabel='ID'>

# %% [markdown]
# ### Colunas das dificuldades (c_dif_#)
# Vamos repetir os passos anteriores
# 1. Isolar as colunas respectivas (subset4)
# 2. Identificar os valores unicos (criteria_list4)
# 3. Criar uma coluna por cada valor unico
# 4. Preencher com True/False (sim/nao) com base nos valores do subset
# 5. Eliminar subset4 da base de dados atualizada

# %%
incubados_updated3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64 entries, 1 to 64
# Data columns (total 50 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   p_name                         57 non-null     object
#  1   p_age                          64 non-null     object
#  2   p_gender                       64 non-null     object
#  3   p_literacy                     64 non-null     object
#  4   inc_name                       64 non-null     object
#  5   c_name                         55 non-null     object
#  6   c_location                     63 non-null     object
#  7   c_employees                    64 non-null     object
#  8   c_age                          63 non-null     object
#  9   c_inapem?                      63 non-null     object
#  10  c_size                         64 non-null     object
#  11  c_resident_time                64 non-null     object
#  12  c_stage                        64 non-null     object
#  13  c_linkto_inc                   64 non-null     object
#  14  c_dif_1                        56 non-null     object
#  15  c_dif_2                        20 non-null     object
#  16  c_dif_3                        6 non-null      object
#  17  c_dif_4                        1 non-null      object
#  18  c_inc_value_1                  57 non-null     object
#  19  c_inc_value_2                  17 non-null     object
#  20  c_inc_value_3                  6 non-null      object
#  21  c_inc_value_4                  2 non-null      object
#  22  c_inc_result_1                 60 non-null     object
#  23  c_inc_result_2                 28 non-null     object
#  24  c_inc_result_3                 10 non-null     object
#  25  c_inc_link_uni?                59 non-null     object
#  26  c_inc_pos_support?             49 non-null     object
#  27  c_act_sector_O                 64 non-null     bool
#  28  c_act_sector_K                 64 non-null     bool
#  29  c_act_sector_H                 64 non-null     bool
#  30  c_act_sector_M                 64 non-null     bool
#  31  c_act_sector_A                 64 non-null     bool
#  32  c_act_sector_C                 64 non-null     bool
#  33  c_act_sector_F                 64 non-null     bool
#  34  c_act_sector_J                 64 non-null     bool
#  35  c_act_sector_E                 64 non-null     bool
#  36  c_act_sector_G                 64 non-null     bool
#  37  c_act_sector_I                 64 non-null     bool
#  38  c_act_sector_N                 64 non-null     bool
#  39  c_knw_trans_mrkt               64 non-null     bool
#  40  c_knw_trans_hr                 64 non-null     bool
#  41  c_knw_trans_sales              64 non-null     bool
#  42  c_knw_trans_legal              64 non-null     bool
#  43  c_knw_trans_entrpre            64 non-null     bool
#  44  c_knw_trans_strt               64 non-null     bool
#  45  c_knw_trans_finc               64 non-null     bool
#  46  c_knw_trans_tool_manuais       64 non-null     bool
#  47  c_knw_trans_tool_training      64 non-null     bool
#  48  c_knw_trans_tool_benchmarking  64 non-null     bool
#  49  c_knw_trans_tool_forums        64 non-null     bool
# dtypes: bool(23), object(27)
# memory usage: 15.4+ KB

# %%
#da lista de colunas acima identificam-se as colinas 14:18
subset4 = incubados_updated2.iloc[:,14:18]
subset4
# Out:
#                                               c_dif_1  \
# ID
# 1               Ausência de Infra-estruturas Físicas
# 2            Acesso a financiamentos e investimentos
# 3            Acesso a financiamentos e investimentos
# 4            Acesso a financiamentos e investimentos
# 5            Acesso a financiamentos e investimentos
# ..                                                ...
# 60           Acesso a financiamentos e investimentos
# 61  Ausência de conhecimento técnico e tecnológico...
# 62           Acesso a financiamentos e investimentos
# 63           Acesso a financiamentos e investimentos
# 64           Acesso a financiamentos e investimentos
#
#                                               c_dif_2  \
# ID
# 1                                                 NaN
# 2   Ausência ou baixa experiência em gestão empres...
# 3                                                 NaN
# 4                                                 NaN
# 5               Ausência de Infra-estruturas Físicas
# ..                                                ...
# 60                                                NaN
# 61              Ausência de Infra-estruturas Físicas
# 62  Ausência ou baixa experiência em gestão empres...
# 63                                                NaN
# 64                                                NaN
#
#                                  c_dif_3 c_dif_4
# ID
# 1                                    NaN     NaN
# 2                                    NaN     NaN
# 3                                    NaN     NaN
# 4                                    NaN     NaN
# 5                                    NaN     NaN
# ..                                   ...     ...
# 60                                   NaN     NaN
# 61                                   NaN     NaN
# 62  Baixa qualificação dos funcionários      NaN
# 63                                   NaN     NaN
# 64                                   NaN     NaN
#
# [64 rows x 4 columns]

# %%
subset4.notnull().sum()
# Out:
# c_dif_1    56
# c_dif_2    20
# c_dif_3     6
# c_dif_4     1
# dtype: int64

# %%
criteria_list4 = [
    'Acesso a financiamentos e investimentos ',
    'Ausência de conhecimento técnico e tecnológico para elaboração do Plano de negócios ',
    'Ausência de Infra-estruturas Físicas ',
    'Ausência ou baixa experiência em gestão empresarial  ',
    'Baixa qualificação dos funcionários ',
    'Pouca ou nenhuma noção sobre empreendedorismo ',
    ]

# %%
results4 = transpose_values(criteria_list4,subset4)
results4.sum(axis=0)
# Out:
# Acesso a financiamentos e investimentos                                                 51
# Ausência de conhecimento técnico e tecnológico para elaboração do Plano de negócios      9
# Ausência de Infra-estruturas Físicas                                                    11
# Ausência ou baixa experiência em gestão empresarial                                      6
# Baixa qualificação dos funcionários                                                      5
# Pouca ou nenhuma noção sobre empreendedorismo                                            1
# dtype: int64

# %%
results4
# Out:
#     Acesso a financiamentos e investimentos   \
# ID
# 1                                      False
# 2                                       True
# 3                                       True
# 4                                       True
# 5                                       True
# ..                                       ...
# 60                                      True
# 61                                     False
# 62                                      True
# 63                                      True
# 64                                      True
#
#     Ausência de conhecimento técnico e tecnológico para elaboração do Plano de negócios   \
# ID
# 1                                               False
# 2                                               False
# 3                                               False
# 4                                               False
# 5                                               False
# ..                                                ...
# 60                                              False
# 61                                               True
# 62                                              False
# 63                                              False
# 64                                              False
#
#     Ausência de Infra-estruturas Físicas   \
# ID
# 1                                    True
# 2                                   False
# 3                                   False
# 4                                   False
# 5                                    True
# ..                                    ...
# 60                                  False
# 61                                   True
# 62                                  False
# 63                                  False
# 64                                  False
#
#     Ausência ou baixa experiência em gestão empresarial    \
# ID
# 1                                               False
# 2                                                True
# 3                                               False
# 4                                               False
# 5                                               False
# ..                                                ...
# 60                                              False
# 61                                              False
# 62                                               True
# 63                                              False
# 64                                              False
#
#     Baixa qualificação dos funcionários   \
# ID
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
# 5                                  False
# ..                                   ...
# 60                                 False
# 61                                 False
# 62                                  True
# 63                                 False
# 64                                 False
#
#     Pouca ou nenhuma noção sobre empreendedorismo
# ID
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
# 5                                            False
# ..                                             ...
# 60                                           False
# 61                                           False
# 62                                           False
# 63                                           False
# 64                                           False
#
# [64 rows x 6 columns]

# %%
#renomear as colunas para a convençao utilizada
results4.columns
# Out:
# Index(['Acesso a financiamentos e investimentos ',
#        'Ausência de conhecimento técnico e tecnológico para elaboração do Plano de negócios ',
#        'Ausência de Infra-estruturas Físicas ',
#        'Ausência ou baixa experiência em gestão empresarial  ',
#        'Baixa qualificação dos funcionários ',
#        'Pouca ou nenhuma noção sobre empreendedorismo '],
#       dtype='object')

# %%
short4 = ['funds',
       'bplan',
       'place',
       'manag_xp',
       'skills',
       'entrep']
clean_columns4 = ["c_dif_"+item for item in short4]

clean_columns4 = dict(zip(criteria_list4,clean_columns4))
results4.rename(columns = clean_columns4, inplace=True)

# %%
results4
# Out:
#     c_dif_funds  c_dif_bplan  c_dif_place  c_dif_manag_xp  c_dif_skills  \
# ID
# 1         False        False         True           False         False
# 2          True        False        False            True         False
# 3          True        False        False           False         False
# 4          True        False        False           False         False
# 5          True        False         True           False         False
# ..          ...          ...          ...             ...           ...
# 60         True        False        False           False         False
# 61        False         True         True           False         False
# 62         True        False        False            True          True
# 63         True        False        False           False         False
# 64         True        False        False           False         False
#
#     c_dif_entrep
# ID
# 1          False
# 2          False
# 3          False
# 4          False
# 5          False
# ..           ...
# 60         False
# 61         False
# 62         False
# 63         False
# 64         False
#
# [64 rows x 6 columns]

# %%
#juntar o resultado ao dataset original e apagar as colunas anteriores
incubados_updated4 = pd.concat([incubados_updated3, results4], axis=1 )
incubados_updated4.drop(subset4.columns, axis=1,inplace=True)

# %%
plt.figure(figsize=(15,5))
sns.heatmap(incubados_updated4.notnull(), linewidths=1, cbar=False)
# Out:
# <AxesSubplot:ylabel='ID'>

# %% [markdown]
# ### Colunas do valor adicionado pela incubdor (c_inc_value_#)
# Vamos repetir os passos anteriores
# 1. Isolar as colunas respectivas (subset5)
# 2. Identificar os valores unicos (criteria_list5)
# 3. Criar uma coluna por cada valor unico
# 4. Preencher com True/False (sim/nao) com base nos valores do subset
# 5. Eliminar subset5 da base de dados atualizada

# %%
incubados_updated4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64 entries, 1 to 64
# Data columns (total 52 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   p_name                         57 non-null     object
#  1   p_age                          64 non-null     object
#  2   p_gender                       64 non-null     object
#  3   p_literacy                     64 non-null     object
#  4   inc_name                       64 non-null     object
#  5   c_name                         55 non-null     object
#  6   c_location                     63 non-null     object
#  7   c_employees                    64 non-null     object
#  8   c_age                          63 non-null     object
#  9   c_inapem?                      63 non-null     object
#  10  c_size                         64 non-null     object
#  11  c_resident_time                64 non-null     object
#  12  c_stage                        64 non-null     object
#  13  c_linkto_inc                   64 non-null     object
#  14  c_inc_value_1                  57 non-null     object
#  15  c_inc_value_2                  17 non-null     object
#  16  c_inc_value_3                  6 non-null      object
#  17  c_inc_value_4                  2 non-null      object
#  18  c_inc_result_1                 60 non-null     object
#  19  c_inc_result_2                 28 non-null     object
#  20  c_inc_result_3                 10 non-null     object
#  21  c_inc_link_uni?                59 non-null     object
#  22  c_inc_pos_support?             49 non-null     object
#  23  c_act_sector_O                 64 non-null     bool
#  24  c_act_sector_K                 64 non-null     bool
#  25  c_act_sector_H                 64 non-null     bool
#  26  c_act_sector_M                 64 non-null     bool
#  27  c_act_sector_A                 64 non-null     bool
#  28  c_act_sector_C                 64 non-null     bool
#  29  c_act_sector_F                 64 non-null     bool
#  30  c_act_sector_J                 64 non-null     bool
#  31  c_act_sector_E                 64 non-null     bool
#  32  c_act_sector_G                 64 non-null     bool
#  33  c_act_sector_I                 64 non-null     bool
#  34  c_act_sector_N                 64 non-null     bool
#  35  c_knw_trans_mrkt               64 non-null     bool
#  36  c_knw_trans_hr                 64 non-null     bool
#  37  c_knw_trans_sales              64 non-null     bool
#  38  c_knw_trans_legal              64 non-null     bool
#  39  c_knw_trans_entrpre            64 non-null     bool
#  40  c_knw_trans_strt               64 non-null     bool
#  41  c_knw_trans_finc               64 non-null     bool
#  42  c_knw_trans_tool_manuais       64 non-null     bool
#  43  c_knw_trans_tool_training      64 non-null     bool
#  44  c_knw_trans_tool_benchmarking  64 non-null     bool
#  45  c_knw_trans_tool_forums        64 non-null     bool
#  46  c_dif_funds                    64 non-null     bool
#  47  c_dif_bplan                    64 non-null     bool
#  48  c_dif_place                    64 non-null     bool
#  49  c_dif_manag_xp                 64 non-null     bool
#  50  c_dif_skills                   64 non-null     bool
#  51  c_dif_entrep                   64 non-null     bool
# dtypes: bool(29), object(23)
# memory usage: 13.8+ KB

# %%
#da lista de colunas acima identificam-se as colinas 14:18
subset5 = incubados_updated4.iloc[:,14:18]
subset5
# Out:
#                               c_inc_value_1          c_inc_value_2  \
# ID
# 1                     Ferramentas de gestão  Recursos Tecnológicos
# 2                     Recursos Tecnológicos                    NaN
# 3         Desenvolvimento de novos produtos                    NaN
# 4   Acesso a redes de empresas já incubadas                    NaN
# 5                     Ferramentas de gestão  Recursos Tecnológicos
# ..                                      ...                    ...
# 60  Acesso a redes de empresas já incubadas                    NaN
# 61  Acesso a redes de empresas já incubadas                    NaN
# 62                    Ferramentas de gestão  Recursos Tecnológicos
# 63                    Recursos Tecnológicos                    NaN
# 64                    Ferramentas de gestão                    NaN
#
#                         c_inc_value_3                 c_inc_value_4
# ID
# 1        Desenvolvimento do Marketing                           NaN
# 2                                 NaN                           NaN
# 3                                 NaN                           NaN
# 4                                 NaN                           NaN
# 5        Desenvolvimento do Marketing                           NaN
# ..                                ...                           ...
# 60                                NaN                           NaN
# 61                                NaN                           NaN
# 62  Desenvolvimento de novos produtos  Desenvolvimento do Marketing
# 63                                NaN                           NaN
# 64                                NaN                           NaN
#
# [64 rows x 4 columns]

# %%
subset5.notnull().sum()
# Out:
# c_inc_value_1    57
# c_inc_value_2    17
# c_inc_value_3     6
# c_inc_value_4     2
# dtype: int64

# %%
subset5['c_inc_value_1'].unique()
# Out:
# array(['Ferramentas de gestão', 'Recursos Tecnológicos',
#        'Desenvolvimento de novos produtos',
#        'Acesso a redes de empresas já incubadas',
#        'Desenvolvimento do Marketing', nan, 'Obtenção de Divisas ',
#        'Acesso ao Crédito'], dtype=object)

# %%
criteria_list5 = ['Ferramentas de gestão', 'Recursos Tecnológicos',
       'Desenvolvimento de novos produtos',
       'Acesso a redes de empresas já incubadas',
       'Desenvolvimento do Marketing', 'Obtenção de Divisas ',
       'Acesso ao Crédito']

# %%
results5 = transpose_values(criteria_list5,subset5)
results5.sum(axis=0)
# Out:
# Ferramentas de gestão                      15
# Recursos Tecnológicos                      16
# Desenvolvimento de novos produtos           8
# Acesso a redes de empresas já incubadas    22
# Desenvolvimento do Marketing               14
# Obtenção de Divisas                         3
# Acesso ao Crédito                           4
# dtype: int64

# %%
results5
# Out:
#     Ferramentas de gestão  Recursos Tecnológicos  \
# ID
# 1                    True                   True
# 2                   False                   True
# 3                   False                  False
# 4                   False                  False
# 5                    True                   True
# ..                    ...                    ...
# 60                  False                  False
# 61                  False                  False
# 62                   True                   True
# 63                  False                   True
# 64                   True                  False
#
#     Desenvolvimento de novos produtos  \
# ID
# 1                               False
# 2                               False
# 3                                True
# 4                               False
# 5                               False
# ..                                ...
# 60                              False
# 61                              False
# 62                               True
# 63                              False
# 64                              False
#
#     Acesso a redes de empresas já incubadas  Desenvolvimento do Marketing  \
# ID
# 1                                     False                          True
# 2                                     False                         False
# 3                                     False                         False
# 4                                      True                         False
# 5                                     False                          True
# ..                                      ...                           ...
# 60                                     True                         False
# 61                                     True                         False
# 62                                    False                          True
# 63                                    False                         False
# 64                                    False                         False
#
#     Obtenção de Divisas   Acesso ao Crédito
# ID
# 1                  False              False
# 2                  False              False
# 3                  False              False
# 4                  False              False
# 5                  False              False
# ..                   ...                ...
# 60                 False              False
# 61                 False              False
# 62                 False              False
# 63                 False              False
# 64                 False              False
#
# [64 rows x 7 columns]

# %%
#renomear as colunas para a convençao utilizada
results5.columns
# Out:
# Index(['Ferramentas de gestão', 'Recursos Tecnológicos',
#        'Desenvolvimento de novos produtos',
#        'Acesso a redes de empresas já incubadas',
#        'Desenvolvimento do Marketing', 'Obtenção de Divisas ',
#        'Acesso ao Crédito'],
#       dtype='object')

# %%
short5 = ['manag_tools', 'tek_res',
       'new_prod',
       'network',
       'markt', 'divisas',
       'credit']
clean_columns5 = ["c_inc_value_"+item for item in short5]

clean_columns5 = dict(zip(criteria_list5,clean_columns5))
results5.rename(columns = clean_columns5, inplace=True)

# %%
results5
# Out:
#     c_inc_value_manag_tools  c_inc_value_tek_res  c_inc_value_new_prod  \
# ID
# 1                      True                 True                 False
# 2                     False                 True                 False
# 3                     False                False                  True
# 4                     False                False                 False
# 5                      True                 True                 False
# ..                      ...                  ...                   ...
# 60                    False                False                 False
# 61                    False                False                 False
# 62                     True                 True                  True
# 63                    False                 True                 False
# 64                     True                False                 False
#
#     c_inc_value_network  c_inc_value_markt  c_inc_value_divisas  \
# ID
# 1                 False               True                False
# 2                 False              False                False
# 3                 False              False                False
# 4                  True              False                False
# 5                 False               True                False
# ..                  ...                ...                  ...
# 60                 True              False                False
# 61                 True              False                False
# 62                False               True                False
# 63                False              False                False
# 64                False              False                False
#
#     c_inc_value_credit
# ID
# 1                False
# 2                False
# 3                False
# 4                False
# 5                False
# ..                 ...
# 60               False
# 61               False
# 62               False
# 63               False
# 64               False
#
# [64 rows x 7 columns]

# %%
#juntar o resultado ao dataset original e apagar as colunas anteriores
incubados_updated5 = pd.concat([incubados_updated4, results5], axis=1 )
incubados_updated5.drop(subset5.columns, axis=1,inplace=True)

# %%
plt.figure(figsize=(15,5))
sns.heatmap(incubados_updated5.notnull(), linewidths=1, cbar=False)
# Out:
# <AxesSubplot:ylabel='ID'>

# %% [markdown]
# ### Colunas dos resultados derivados da incubadora (c_inc_result_#)
# Vamos repetir os passos anteriores
# 1. Isolar as colunas respectivas (subset5)
# 2. Identificar os valores unicos (criteria_list5)
# 3. Criar uma coluna por cada valor unico
# 4. Preencher com True/False (sim/nao) com base nos valores do subset
# 5. Eliminar subset5 da base de dados atualizada

# %%
incubados_updated5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64 entries, 1 to 64
# Data columns (total 55 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   p_name                         57 non-null     object
#  1   p_age                          64 non-null     object
#  2   p_gender                       64 non-null     object
#  3   p_literacy                     64 non-null     object
#  4   inc_name                       64 non-null     object
#  5   c_name                         55 non-null     object
#  6   c_location                     63 non-null     object
#  7   c_employees                    64 non-null     object
#  8   c_age                          63 non-null     object
#  9   c_inapem?                      63 non-null     object
#  10  c_size                         64 non-null     object
#  11  c_resident_time                64 non-null     object
#  12  c_stage                        64 non-null     object
#  13  c_linkto_inc                   64 non-null     object
#  14  c_inc_result_1                 60 non-null     object
#  15  c_inc_result_2                 28 non-null     object
#  16  c_inc_result_3                 10 non-null     object
#  17  c_inc_link_uni?                59 non-null     object
#  18  c_inc_pos_support?             49 non-null     object
#  19  c_act_sector_O                 64 non-null     bool
#  20  c_act_sector_K                 64 non-null     bool
#  21  c_act_sector_H                 64 non-null     bool
#  22  c_act_sector_M                 64 non-null     bool
#  23  c_act_sector_A                 64 non-null     bool
#  24  c_act_sector_C                 64 non-null     bool
#  25  c_act_sector_F                 64 non-null     bool
#  26  c_act_sector_J                 64 non-null     bool
#  27  c_act_sector_E                 64 non-null     bool
#  28  c_act_sector_G                 64 non-null     bool
#  29  c_act_sector_I                 64 non-null     bool
#  30  c_act_sector_N                 64 non-null     bool
#  31  c_knw_trans_mrkt               64 non-null     bool
#  32  c_knw_trans_hr                 64 non-null     bool
#  33  c_knw_trans_sales              64 non-null     bool
#  34  c_knw_trans_legal              64 non-null     bool
#  35  c_knw_trans_entrpre            64 non-null     bool
#  36  c_knw_trans_strt               64 non-null     bool
#  37  c_knw_trans_finc               64 non-null     bool
#  38  c_knw_trans_tool_manuais       64 non-null     bool
#  39  c_knw_trans_tool_training      64 non-null     bool
#  40  c_knw_trans_tool_benchmarking  64 non-null     bool
#  41  c_knw_trans_tool_forums        64 non-null     bool
#  42  c_dif_funds                    64 non-null     bool
#  43  c_dif_bplan                    64 non-null     bool
#  44  c_dif_place                    64 non-null     bool
#  45  c_dif_manag_xp                 64 non-null     bool
#  46  c_dif_skills                   64 non-null     bool
#  47  c_dif_entrep                   64 non-null     bool
#  48  c_inc_value_manag_tools        64 non-null     bool
#  49  c_inc_value_tek_res            64 non-null     bool
#  50  c_inc_value_new_prod           64 non-null     bool
#  51  c_inc_value_network            64 non-null     bool
#  52  c_inc_value_markt              64 non-null     bool
#  53  c_inc_value_divisas            64 non-null     bool
#  54  c_inc_value_credit             64 non-null     bool
# dtypes: bool(36), object(19)
# memory usage: 12.2+ KB

# %%
#da lista de colunas acima identificam-se as colinas 14:17
subset6 = incubados_updated5.iloc[:,14:17]
subset6
# Out:
#                                        c_inc_result_1  \
# ID
# 1                                                 NaN
# 2     Rede de contactos para oportunidades de negócio
# 3       Parcerias com empresas já firmadas no mercado
# 4   A grande visibilidade que a Incubadora proporc...
# 5   A grande visibilidade que a Incubadora proporc...
# ..                                                ...
# 60    Rede de contactos para oportunidades de negócio
# 61    Rede de contactos para oportunidades de negócio
# 62    Rede de contactos para oportunidades de negócio
# 63                         Internet banda larga 24/24
# 64    Rede de contactos para oportunidades de negócio
#
#                                    c_inc_result_2  \
# ID
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5   Parcerias com empresas já firmadas no mercado
# ..                                            ...
# 60                     Internet banda larga 24/24
# 61                     Internet banda larga 24/24
# 62                     Internet banda larga 24/24
# 63             Não pagar a renda de um escritório
# 64                     Internet banda larga 24/24
#
#                         c_inc_result_3
# ID
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# ..                                 ...
# 60  Não pagar a renda de um escritório
# 61  Não pagar a renda de um escritório
# 62  Não pagar a renda de um escritório
# 63                                 NaN
# 64  Não pagar a renda de um escritório
#
# [64 rows x 3 columns]

# %%
subset6.notnull().sum()
# Out:
# c_inc_result_1    60
# c_inc_result_2    28
# c_inc_result_3    10
# dtype: int64

# %%
subset6['c_inc_result_1'].value_counts()
# Out:
# Rede de contactos para oportunidades de negócio                 30
# A grande visibilidade que a Incubadora proporciona a Empresa    14
# Internet banda larga 24/24                                       7
# Parcerias com empresas já firmadas no mercado                    5
# Não pagar a renda de um escritório                               4
# Name: c_inc_result_1, dtype: int64

# %%
subset6['c_inc_result_1'].unique()
# Out:
# array([nan, 'Rede de contactos para oportunidades de negócio',
#        'Parcerias com empresas já firmadas no mercado',
#        'A grande visibilidade que a Incubadora proporciona a Empresa',
#        'Não pagar a renda de um escritório', 'Internet banda larga 24/24'],
#       dtype=object)

# %%
criteria_list6 = ['Rede de contactos para oportunidades de negócio',
       'Parcerias com empresas já firmadas no mercado',
       'A grande visibilidade que a Incubadora proporciona a Empresa',
       'Não pagar a renda de um escritório', 'Internet banda larga 24/24']

# %%
results6 = transpose_values(criteria_list6,subset6)
results6.sum(axis=0)
# Out:
# Rede de contactos para oportunidades de negócio                 30
# Parcerias com empresas já firmadas no mercado                   13
# A grande visibilidade que a Incubadora proporciona a Empresa    27
# Não pagar a renda de um escritório                              15
# Internet banda larga 24/24                                      13
# dtype: int64

# %%
results6
# Out:
#     Rede de contactos para oportunidades de negócio  \
# ID
# 1                                             False
# 2                                              True
# 3                                             False
# 4                                             False
# 5                                             False
# ..                                              ...
# 60                                             True
# 61                                             True
# 62                                             True
# 63                                            False
# 64                                             True
#
#     Parcerias com empresas já firmadas no mercado  \
# ID
# 1                                           False
# 2                                           False
# 3                                            True
# 4                                           False
# 5                                            True
# ..                                            ...
# 60                                          False
# 61                                          False
# 62                                          False
# 63                                          False
# 64                                          False
#
#     A grande visibilidade que a Incubadora proporciona a Empresa  \
# ID
# 1                                               False
# 2                                               False
# 3                                               False
# 4                                                True
# 5                                                True
# ..                                                ...
# 60                                              False
# 61                                              False
# 62                                              False
# 63                                              False
# 64                                              False
#
#     Não pagar a renda de um escritório  Internet banda larga 24/24
# ID
# 1                                False                       False
# 2                                False                       False
# 3                                False                       False
# 4                                False                       False
# 5                                False                       False
# ..                                 ...                         ...
# 60                                True                        True
# 61                                True                        True
# 62                                True                        True
# 63                                True                        True
# 64                                True                        True
#
# [64 rows x 5 columns]

# %%
#renomear as colunas para a convençao utilizada
results6.columns
# Out:
# Index(['Rede de contactos para oportunidades de negócio',
#        'Parcerias com empresas já firmadas no mercado',
#        'A grande visibilidade que a Incubadora proporciona a Empresa',
#        'Não pagar a renda de um escritório', 'Internet banda larga 24/24'],
#       dtype='object')

# %%
short6 = ['network_oport','senior_partn','image','rent','wifi']
clean_columns6 = ["c_inc_vantagem_"+item for item in short6]

clean_columns6 = dict(zip(criteria_list6,clean_columns6))
results6.rename(columns = clean_columns6, inplace=True)

# %%
results6
# Out:
#     c_inc_vantagem_network_oport  c_inc_vantagem_senior_partn  \
# ID
# 1                          False                        False
# 2                           True                        False
# 3                          False                         True
# 4                          False                        False
# 5                          False                         True
# ..                           ...                          ...
# 60                          True                        False
# 61                          True                        False
# 62                          True                        False
# 63                         False                        False
# 64                          True                        False
#
#     c_inc_vantagem_image  c_inc_vantagem_rent  c_inc_vantagem_wifi
# ID
# 1                  False                False                False
# 2                  False                False                False
# 3                  False                False                False
# 4                   True                False                False
# 5                   True                False                False
# ..                   ...                  ...                  ...
# 60                 False                 True                 True
# 61                 False                 True                 True
# 62                 False                 True                 True
# 63                 False                 True                 True
# 64                 False                 True                 True
#
# [64 rows x 5 columns]

# %%
#juntar o resultado ao dataset original e apagar as colunas anteriores
incubados_updated6 = pd.concat([incubados_updated5, results6], axis=1 )
incubados_updated6.drop(subset6.columns, axis=1,inplace=True)

# %%
plt.figure(figsize=(15,5))
sns.heatmap(incubados_updated6.notnull(), linewidths=1, cbar=False)
# Out:
# <AxesSubplot:ylabel='ID'>

# %% [markdown]
# hurray! O dataset está pronto para a análise estatistica. As restantes correções serão efetuadas à medida que se analisa cada uma das variáveis.

# %% [markdown]
# ### Simplificação das Variáveis Categóricas

# %% [markdown]
# #### Idade dos incubados p_age

# %%
incubados_updated6['p_age'].describe()
# Out:
# count                  64
# unique                  4
# top       De 25 a 34 anos
# freq                   42
# Name: p_age, dtype: object

# %%
incubados_updated6['p_age'] = incubados_updated6['p_age'].str.replace("De","").str.replace(" anos","").str.replace(" a ","-")

# %%
incubados_updated6['p_age'].value_counts(dropna=False)
# Out:
#  25-34    42
#  35-44    11
#  18-24    10
#  55-64     1
# Name: p_age, dtype: int64

# %% [markdown]
# #### Genero p_gender

# %%
incubados_updated6['p_gender'].value_counts(dropna=False)
# Out:
# Masculino    57
# Feminino      7
# Name: p_gender, dtype: int64

# %% [markdown]
# #### Grau de Escolaridade p_literacy

# %%
incubados_updated6['p_literacy'].value_counts(dropna=False)
# Out:
# Licenciatura     40
# Técnico Médio    20
# Mestrado          4
# Name: p_literacy, dtype: int64

# %% [markdown]
# #### Incubadora inc_name

# %%
incubados_updated6['inc_name'].value_counts(dropna=False)
# Out:
# Incubadora das TICS INAPEM    17
# CLESE DO UÍGE                 11
# CLESE DO HUAMBO               10
# CLESE DA HUÍLA                 9
# CLESE DE MALANGE               5
# CLESE-SUMBE                    4
# CLESE KUANZA NORTE             3
# IEMP                           1
# CLESE MOXICO                   1
# CLESE DE CABINDA               1
# CLESE BENGUELA                 1
# CLESE DO DUNDO                 1
# Name: inc_name, dtype: int64

# %%
#simplificar nomes e retirar capitalização 

incubados_updated6['inc_name'] = incubados_updated6['inc_name'].str.replace(" DO "," ")
incubados_updated6['inc_name'] = incubados_updated6['inc_name'].str.replace(" DA "," ")
incubados_updated6['inc_name'] = incubados_updated6['inc_name'].str.replace(" DE "," ")
incubados_updated6['inc_name'] = incubados_updated6['inc_name'].str.replace("-"," ")
incubados_updated6['inc_name'] = incubados_updated6['inc_name'].str.replace("Incubadora das TICS ","")
incubados_updated6['inc_name'] = incubados_updated6['inc_name'].str.strip()

# %%
#a maior parte sao de CLESES (centros locais de empreendedorismo e serviços de emprego)
def cap_second(i):
    name = i.split()
    if len(name)>1:
        for n in range(len(name)-1):
            name[n+1]= name[n+1].lower().capitalize()
    return ' '.join(name)

incubados_updated6['inc_name'] = incubados_updated6['inc_name'].apply(cap_second)

# %%
incubados_updated6['inc_name'].value_counts()
# Out:
# INAPEM                17
# CLESE Uíge            11
# CLESE Huambo          10
# CLESE Huíla            9
# CLESE Malange          5
# CLESE Sumbe            4
# CLESE Kuanza Norte     3
# CLESE Cabinda          1
# IEMP                   1
# CLESE Dundo            1
# CLESE Moxico           1
# CLESE Benguela         1
# Name: inc_name, dtype: int64

# %% [markdown]
# #### Nomes da empresa incubada
# Nao será necessária para a analise

# %% [markdown]
# #### Localizaçao da empresa incubada (sede legal?)
# Parece coincidir com a da incubadora, mas poderá ser necessário separar a localidade da cidade, considerando a maior complexidade e a  incerteza dos critérios, eventuais correções aos  dados serão efetuadas em sede de analise

# %%
incubados_updated6['c_location'].value_counts() #a verificar necessidades com localização
# Out:
# Uíge                          11
# Huíla - Lubango                9
# Huambo                         9
# Luanda                         6
# Luanda-Ingombotas              5
# Malange - sede                 4
# CUANZA SUL- SUMBE              3
# Cuanza Norte ( Ndalatando)     3
# Luanda, Cassenda               1
# Luanda-Morro Bento             1
# Moxico                         1
# Luanda - Rua da Missão         1
# Lunda Norte, Dundo             1
# Luanda- Belas                  1
# Huambo, Benguela e Luanda      1
# luanda                         1
# Luanda, Kilamba                1
#  Malange                       1
# CABINDA, MUNICÍPIO SEDE.       1
# Luanda( Belas )                1
# Benguela                       1
# Name: c_location, dtype: int64

# %% [markdown]
# #### Idade da empresa incubada c_age
# será efetuada apenas a limpeza para encurtar o nome dos grupos etários

# %%
incubados_updated6['c_age'] = incubados_updated6['c_age'].str.replace("De","").str.replace(" anos","").str.replace(" a "," - ").str.replace(" ano","").str.replace("Mais de ","> ").str.strip()

# %%
incubados_updated6['c_age'].value_counts()
# Out:
# 3 - 5     30
# 1 - 2     14
# 0 - 1     13
# > 10       3
# 6 - 10     3
# Name: c_age, dtype: int64

# %% [markdown]
# #### Numero de empregados na empresa
# será efetuada apenas a limpeza para encurtar o nome dos grupos

# %%
incubados_updated6['c_employees'].value_counts()
# Out:
# Entre 1 e 10      53
# Entre 10 e 100    11
# Name: c_employees, dtype: int64

# %%
incubados_updated6['c_employees'] = incubados_updated6['c_employees'].str.replace("Entre ","").str.replace(" e "," - ").str.strip()

# %%
incubados_updated6['c_employees'].value_counts()
# Out:
# 1 - 10      53
# 10 - 100    11
# Name: c_employees, dtype: int64

# %% [markdown]
# #### Tempo de residencia da empresa na incubadora c_resident_time(years)
# Este sendo o unico valor que pode ser numérico, vamos transformar esta coluna dados decimais (float)

# %%
incubados_updated6['c_resident_time'] = incubados_updated6['c_resident_time'].str.lower().str.replace("6 meses","0.5").str.replace('ano','').str.replace('s','').str.replace('mai de ','')

# %%
incubados_updated6['c_resident_time'].astype(float)
# uma vez que existem valores em meses e em anos, passamos tudo para anos e renomeamos as coluna para incluir a unidade
incubados_updated6.rename(columns={'c_resident_time':'c_resident_years'},inplace=True)

# %%
incubados_updated6['c_resident_years'].value_counts()
# Out:
# 0.5     23
# 1       16
# 3       10
# 2        8
# 4        7
# Name: c_resident_years, dtype: int64

# %%
incubados_updated6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64 entries, 1 to 64
# Data columns (total 57 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   p_name                         57 non-null     object
#  1   p_age                          64 non-null     object
#  2   p_gender                       64 non-null     object
#  3   p_literacy                     64 non-null     object
#  4   inc_name                       64 non-null     object
#  5   c_name                         55 non-null     object
#  6   c_location                     63 non-null     object
#  7   c_employees                    64 non-null     object
#  8   c_age                          63 non-null     object
#  9   c_inapem?                      63 non-null     object
#  10  c_size                         64 non-null     object
#  11  c_resident_years               64 non-null     object
#  12  c_stage                        64 non-null     object
#  13  c_linkto_inc                   64 non-null     object
#  14  c_inc_link_uni?                59 non-null     object
#  15  c_inc_pos_support?             49 non-null     object
#  16  c_act_sector_O                 64 non-null     bool
#  17  c_act_sector_K                 64 non-null     bool
#  18  c_act_sector_H                 64 non-null     bool
#  19  c_act_sector_M                 64 non-null     bool
#  20  c_act_sector_A                 64 non-null     bool
#  21  c_act_sector_C                 64 non-null     bool
#  22  c_act_sector_F                 64 non-null     bool
#  23  c_act_sector_J                 64 non-null     bool
#  24  c_act_sector_E                 64 non-null     bool
#  25  c_act_sector_G                 64 non-null     bool
#  26  c_act_sector_I                 64 non-null     bool
#  27  c_act_sector_N                 64 non-null     bool
#  28  c_knw_trans_mrkt               64 non-null     bool
#  29  c_knw_trans_hr                 64 non-null     bool
#  30  c_knw_trans_sales              64 non-null     bool
#  31  c_knw_trans_legal              64 non-null     bool
#  32  c_knw_trans_entrpre            64 non-null     bool
#  33  c_knw_trans_strt               64 non-null     bool
#  34  c_knw_trans_finc               64 non-null     bool
#  35  c_knw_trans_tool_manuais       64 non-null     bool
#  36  c_knw_trans_tool_training      64 non-null     bool
#  37  c_knw_trans_tool_benchmarking  64 non-null     bool
#  38  c_knw_trans_tool_forums        64 non-null     bool
#  39  c_dif_funds                    64 non-null     bool
#  40  c_dif_bplan                    64 non-null     bool
#  41  c_dif_place                    64 non-null     bool
#  42  c_dif_manag_xp                 64 non-null     bool
#  43  c_dif_skills                   64 non-null     bool
#  44  c_dif_entrep                   64 non-null     bool
#  45  c_inc_value_manag_tools        64 non-null     bool
#  46  c_inc_value_tek_res            64 non-null     bool
#  47  c_inc_value_new_prod           64 non-null     bool
#  48  c_inc_value_network            64 non-null     bool
#  49  c_inc_value_markt              64 non-null     bool
#  50  c_inc_value_divisas            64 non-null     bool
#  51  c_inc_value_credit             64 non-null     bool
#  52  c_inc_vantagem_network_oport   64 non-null     bool
#  53  c_inc_vantagem_senior_partn    64 non-null     bool
#  54  c_inc_vantagem_image           64 non-null     bool
#  55  c_inc_vantagem_rent            64 non-null     bool
#  56  c_inc_vantagem_wifi            64 non-null     bool
# dtypes: bool(41), object(16)
# memory usage: 11.1+ KB

# %% [markdown]
# #### Atualização do tipo das variáveis para categoricas ou boolean

# %%
incubados_updated6[incubados_updated6.columns[1:5]] = incubados_updated6[incubados_updated6.columns[1:5]].astype("category")
incubados_updated6[incubados_updated6.columns[6:9]] = incubados_updated6[incubados_updated6.columns[6:9]].astype("category")
incubados_updated6[incubados_updated6.columns[12:14]] = incubados_updated6[incubados_updated6.columns[12:14]].astype("category")
incubados_updated6[incubados_updated6.columns[9]] = incubados_updated6[incubados_updated6.columns[9]].astype("boolean")
incubados_updated6[incubados_updated6.columns[11]] = incubados_updated6[incubados_updated6.columns[11]].astype("float")
incubados_updated6[incubados_updated6.columns[14:]] = incubados_updated6[incubados_updated6.columns[14:]].astype("boolean")
incubados_updated6[incubados_updated6.columns[10]] = incubados_updated6[incubados_updated6.columns[10]].astype("category")

# %%
incubados_updated6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64 entries, 1 to 64
# Data columns (total 57 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   p_name                         57 non-null     object
#  1   p_age                          64 non-null     category
#  2   p_gender                       64 non-null     category
#  3   p_literacy                     64 non-null     category
#  4   inc_name                       64 non-null     category
#  5   c_name                         55 non-null     object
#  6   c_location                     63 non-null     category
#  7   c_employees                    64 non-null     category
#  8   c_age                          63 non-null     category
#  9   c_inapem?                      63 non-null     boolean
#  10  c_size                         64 non-null     category
#  11  c_resident_years               64 non-null     float64
#  12  c_stage                        64 non-null     category
#  13  c_linkto_inc                   64 non-null     category
#  14  c_inc_link_uni?                59 non-null     boolean
#  15  c_inc_pos_support?             49 non-null     boolean
#  16  c_act_sector_O                 64 non-null     boolean
#  17  c_act_sector_K                 64 non-null     boolean
#  18  c_act_sector_H                 64 non-null     boolean
#  19  c_act_sector_M                 64 non-null     boolean
#  20  c_act_sector_A                 64 non-null     boolean
#  21  c_act_sector_C                 64 non-null     boolean
#  22  c_act_sector_F                 64 non-null     boolean
#  23  c_act_sector_J                 64 non-null     boolean
#  24  c_act_sector_E                 64 non-null     boolean
#  25  c_act_sector_G                 64 non-null     boolean
#  26  c_act_sector_I                 64 non-null     boolean
#  27  c_act_sector_N                 64 non-null     boolean
#  28  c_knw_trans_mrkt               64 non-null     boolean
#  29  c_knw_trans_hr                 64 non-null     boolean
#  30  c_knw_trans_sales              64 non-null     boolean
#  31  c_knw_trans_legal              64 non-null     boolean
#  32  c_knw_trans_entrpre            64 non-null     boolean
#  33  c_knw_trans_strt               64 non-null     boolean
#  34  c_knw_trans_finc               64 non-null     boolean
#  35  c_knw_trans_tool_manuais       64 non-null     boolean
#  36  c_knw_trans_tool_training      64 non-null     boolean
#  37  c_knw_trans_tool_benchmarking  64 non-null     boolean
#  38  c_knw_trans_tool_forums        64 non-null     boolean
#  39  c_dif_funds                    64 non-null     boolean
#  40  c_dif_bplan                    64 non-null     boolean
#  41  c_dif_place                    64 non-null     boolean
#  42  c_dif_manag_xp                 64 non-null     boolean
#  43  c_dif_skills                   64 non-null     boolean
#  44  c_dif_entrep                   64 non-null     boolean
#  45  c_inc_value_manag_tools        64 non-null     boolean
#  46  c_inc_value_tek_res            64 non-null     boolean
#  47  c_inc_value_new_prod           64 non-null     boolean
#  48  c_inc_value_network            64 non-null     boolean
#  49  c_inc_value_markt              64 non-null     boolean
#  50  c_inc_value_divisas            64 non-null     boolean
#  51  c_inc_value_credit             64 non-null     boolean
#  52  c_inc_vantagem_network_oport   64 non-null     boolean
#  53  c_inc_vantagem_senior_partn    64 non-null     boolean
#  54  c_inc_vantagem_image           64 non-null     boolean
#  55  c_inc_vantagem_rent            64 non-null     boolean
#  56  c_inc_vantagem_wifi            64 non-null     boolean
# dtypes: boolean(44), category(10), float64(1), object(2)
# memory usage: 10.5+ KB

# %%
incubados_updated6[['c_location','inc_name']].tail(30)
# Out:
#                     c_location            inc_name
# ID
# 35                        Uíge          CLESE Uíge
# 36                        Uíge          CLESE Uíge
# 37                        Uíge          CLESE Uíge
# 38           CUANZA SUL- SUMBE         CLESE Sumbe
# 39           CUANZA SUL- SUMBE         CLESE Sumbe
# 40                         NaN         CLESE Sumbe
# 41           CUANZA SUL- SUMBE         CLESE Sumbe
# 42  Cuanza Norte ( Ndalatando)  CLESE Kuanza Norte
# 43  Cuanza Norte ( Ndalatando)  CLESE Kuanza Norte
# 44  Cuanza Norte ( Ndalatando)  CLESE Kuanza Norte
# 45                      Moxico        CLESE Moxico
# 46                    Benguela      CLESE Benguela
# 47      Luanda - Rua da Missão                IEMP
# 48                      Luanda              INAPEM
# 49                      Luanda              INAPEM
# 50             Luanda, Kilamba              INAPEM
# 51                      Luanda              INAPEM
# 52                      Luanda              INAPEM
# 53                      luanda              INAPEM
# 54               Luanda- Belas              INAPEM
# 55         Luanda-Morro Bento               INAPEM
# 56            Luanda, Cassenda              INAPEM
# 57             Luanda( Belas )              INAPEM
# 58           Luanda-Ingombotas              INAPEM
# 59                      Luanda              INAPEM
# 60           Luanda-Ingombotas              INAPEM
# 61           Luanda-Ingombotas              INAPEM
# 62                      Luanda              INAPEM
# 63           Luanda-Ingombotas              INAPEM
# 64           Luanda-Ingombotas              INAPEM

# %% [markdown]
# #### Eliminação de colunas:
# Como se pode verificar acima, a coluna da localização correponde aos nomes da incubadoras, pelo que esta coluna nao apresenta informaçao adicional.
# Por não apresentarem relevancia e de modo a anonimizar os dados, serão excluidas da análise as seguintes colunas:
#
# |Index|Coluna / Variável         |Tipo |Justificação|
# |:-:|:---------------------------|:----|:-------|
# |1 |p_name                       | text|nome do empreendor, dado sensível|
# |6 |c_name                       | text|nome da empresa, sem significado estatistico|
# |7 |c_location                   | text|corresponde à localizaçao da incubadora, dado redundante, rever|

# %%
incubados_updated6.drop(['p_name','c_name','c_location'], axis=1, inplace=True)

# %% [markdown]
# ### Incubadoras

# %%
#leitura do ficheiro "survey_incubadoras.xls"
incubadoras = pd.read_excel("./data_input/survey_incubadoras.xls", index_col=0, true_values=["Sim"],false_values=["Não"])

# %% [markdown]
# #### Ajustar/alterar nomes das colunas.
# Nesta fase vamos simplificar o nome das colunas de modo a criar uma variável explicativa do racional da pergunta mas mantendo a estrutura tabelar, de forma a facilitar o tratamento estatistico.
#
# As colunas têm os nomes das questões do questionário. Para o objectivo de criar estatistiscas descritivas e gráficos, cada perguntar representa uma variável a caracterizar pelo que será conveniente utilizar nomes mais curtos para facilitar a manipulação, plotagem e análise.

# %%
#nomes  das colunas atuais
incubadoras.columns
# Out:
# Index(['Nome da Incubadora', 'Nome do Gestor', 'Formação do Gestor',
#        'Tempo de actuação na incubadora', 'vinculo_1', 'vinculo_2',
#        'Qual é a tipologia da Incubadora?', 'stage_1', 'stage_2', 'stage_3',
#        'stage_4',
#        'Qual o período de envolvimento das empresas no processo de incubação?',
#        'select_by_projects', 'select_by_ideias', 'select_by_others',
#        'Quantas empresas já foram graduadas pela incubadora? ',
#        'Quantas empresas estão incubadas? ',
#        'É feito o acompanhamento do das empresas incubadas? ',
#        'A incubadora dispunha ou dispõe de algum tipo de aporte financeiro?',
#        'Teve ou tem parceria com elementos de apoio?',
#        'As empresas incubadas beneficiam dessas parcerias?',
#        'A incubadora promove ambientes para interacção entre as empresas incubadas?  ',
#        'handicap_management_knw', 'handicap_management_exp',
#        'handicap_technical_knw', 'handicap_entrepeneur_knw',
#        'A incubadora dispõe de competências técnicas para ajudar as empresas nessas dificuldades?',
#        'manag_knw_1', 'manag_knw_2', 'manag_knw_3', 'manag_knw_4',
#        'manag_knw_5', 'manag_knw_6',
#        'Transfere conhecimento técnico e/ou tecnológico às empresas incubadas?',
#        'knw_transfer_tools_1', 'knw_transfer_tools_2', 'knw_transfer_tools_3',
#        'knw_transfer_tools_4', 'knw_transfer_tools_5', 'knw_transfer_tools_6'],
#       dtype='object')

# %% [markdown]
# simplificaçao dos nomes das colunas 'mais longos'

# %%
# Novos nomes sugeridos
incubadoras_column_names = {'Tempo de actuação na incubadora':'Longevidade do Gestor', 
                          'Qual é a tipologia da Incubadora?':'Tipo de Incubadora',
                          'Qual o período de envolvimento das empresas no processo de incubação?':'Tempo dos Incubados no Processo', 
                          'Quantas empresas já foram graduadas pela incubadora? ':'Total de Incubados',
                          'Quantas empresas estão incubadas? ':'Atuais Incubados',
                          'É feito o acompanhamento do das empresas incubadas? ':'Acompanhamento dos Incubados?', 
                          'A incubadora dispunha ou dispõe de algum tipo de aporte financeiro?':'Suporte Financeiro?',
                          'Teve ou tem parceria com elementos de apoio?':'Parcerias com elementos de Apoio?', 
                          'As empresas incubadas beneficiam dessas parcerias?':'Parcerias extendem para os Incubados?',
                          'A incubadora promove ambientes para interacção entre as empresas incubadas?  ':'Promove Interação entre Incubados?', 
                          'A incubadora dispõe de competências técnicas para ajudar as empresas nessas dificuldades?':'Competencias Técnicas?',
                          'Transfere conhecimento técnico e/ou tecnológico às empresas incubadas?':'Transfere Conhecimento?', 
    }

# %%
incubadoras.rename(columns = incubadoras_column_names, inplace=True)

# %% [markdown]
# #### Análise Inicial e Mapa de Valores Omissos

# %%
plt.figure(figsize=(15,5))
sns.heatmap(incubadoras.notnull(), linewidths=1, cbar=False)
# Out:
# <AxesSubplot:ylabel='ID'>

# %% [markdown]
# **Como se verifica  no heatmap acima, o dataset tem vários valores omissos (a preto), correspondentes a:**
# - linhas vazias
# - colunas vazias e,
# - colunas com poucos valores correspondentes às colunas de escolhar múltipla

# %%
# em primeiro lugar vamos eliminar linhas e colunas completamente vazias:
incubadoras.dropna(axis=0,how="all", inplace=True) #delete all empty rows
incubadoras.dropna(axis=1,how="all", inplace=True) #delete all empty columns

# %% [markdown]
# <div class="alert alert-block alert-info">
# Após a remoção de linhas e colunas vazias, permanecem as colunas de escolha multipla:
#     <ul>
#        <li>VÍnculo 1 e 2</li>
#        <li>Estagios de incubação</li>
#        <li>Critério de seleção de empresas</li>
#        <li>Critério de seleção de empresas</li>
#        <li>Ferramentas de transmissao de conhecimento</li>
#      </ul>
# A estratégia para preecher este valores será a de considerar que os respondentes só assinalam as opções que são verdade para o seu caso (True) e as não assinaladas serão preenchidas com o valor (False).
# Algumas destas colunas foram pré preenchidas com com valores Sim/Não e transformadas em True/False no momento da importação. Os nomes das colunas também poderão ser alterados para refletir a opção assinalada.  Faremos esta analise, coluna a coluna.
# </div>

# %%
incubadoras.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 1 to 11
# Data columns (total 36 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Nome da Incubadora                     11 non-null     object
#  1   Nome do Gestor                         11 non-null     object
#  2   Formação do Gestor                     11 non-null     object
#  3   Longevidade do Gestor                  11 non-null     object
#  4   vinculo_1                              11 non-null     object
#  5   vinculo_2                              2 non-null      object
#  6   Tipo de Incubadora                     11 non-null     object
#  7   stage_1                                11 non-null     object
#  8   stage_2                                4 non-null      object
#  9   stage_3                                1 non-null      object
#  10  Tempo dos Incubados no Processo        11 non-null     object
#  11  select_by_projects                     7 non-null      object
#  12  select_by_ideias                       5 non-null      object
#  13  select_by_others                       1 non-null      object
#  14  Total de Incubados                     11 non-null     object
#  15  Atuais Incubados                       11 non-null     object
#  16  Acompanhamento dos Incubados?          11 non-null     object
#  17  Suporte Financeiro?                    11 non-null     object
#  18  Parcerias com elementos de Apoio?      11 non-null     object
#  19  Parcerias extendem para os Incubados?  11 non-null     object
#  20  Promove Interação entre Incubados?     11 non-null     object
#  21  handicap_management_knw                4 non-null      object
#  22  handicap_management_exp                7 non-null      object
#  23  handicap_technical_knw                 5 non-null      object
#  24  handicap_entrepeneur_knw               2 non-null      object
#  25  Competencias Técnicas?                 11 non-null     object
#  26  manag_knw_1                            11 non-null     object
#  27  manag_knw_2                            8 non-null      object
#  28  manag_knw_3                            6 non-null      object
#  29  manag_knw_4                            4 non-null      object
#  30  manag_knw_5                            3 non-null      object
#  31  manag_knw_6                            2 non-null      object
#  32  Transfere Conhecimento?                11 non-null     object
#  33  knw_transfer_tools_1                   11 non-null     object
#  34  knw_transfer_tools_2                   8 non-null      object
#  35  knw_transfer_tools_3                   3 non-null      object
# dtypes: object(36)
# memory usage: 3.2+ KB

# %% [markdown]
# Verifica se que os dados com os nomes dos gestores são sensíveis e não são necessários à análise pelo que se elimina essa coluna do dataset.

# %%
incubadoras.drop(columns='Nome do Gestor', inplace=True)

# %% [markdown]
# #### Colunas dos Vínculos
# Vamos criar uma variável categorias binomiais (com valores True (sim) e False (não)) com tantas colunas quanto o número de valores unicos na resposta.

# %%
incubadoras[incubadoras.columns[3]].unique() #valores uniques respondidos na primeira coluna
# Out:
# array(['Instituições Empresariais', 'Instituições Sociais',
#        'Instituições Governamentais', 'Outras Instituições'], dtype=object)

# %%
#com base nos valores das respostas, podemos construir a lista de todas as atividades que foram respondidas pelo menos uma vez
criteria_list = ['Instituições Empresariais',
                 'Instituições Sociais',
                 'Instituições Governamentais', 
                 'Outras Instituições']

# %%
subset = incubadoras.iloc[:,3:5] # slice of the dataframe to convert to a new set of columns

# %%
results = transpose_values(criteria_list,subset)
results.sum(axis=1).value_counts()
# Out:
# 1    9
# 2    2
# dtype: int64

# %%
#Eliminamos as antigas colunas que já não são necessárias e adicionamos os resultados 
incubadoras_updated = pd.concat([incubadoras,results], axis=1)
incubadoras_updated.drop(subset.columns, axis=1, inplace=True)

# %%
# alterar nome das colunas criadas
replace_keys= {'Instituições Empresariais':'Vínculo Empresarial',
                 'Instituições Sociais':'Vínculo Social',
                 'Instituições Governamentais':'Vínculo Governamental', 
                 'Outras Instituições':'Outros Vínculos'}
incubadoras_updated.rename(columns=replace_keys, inplace=True)

# %%
plt.figure(figsize=(15,5))
sns.heatmap(incubadoras_updated.notnull(), linewidths=1, cbar=False)
# Out:
# <AxesSubplot:ylabel='ID'>

# %% [markdown]
# #### Colunas Das Fases de Incubação

# %%
incubadoras_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 1 to 11
# Data columns (total 37 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Nome da Incubadora                     11 non-null     object
#  1   Formação do Gestor                     11 non-null     object
#  2   Longevidade do Gestor                  11 non-null     object
#  3   Tipo de Incubadora                     11 non-null     object
#  4   stage_1                                11 non-null     object
#  5   stage_2                                4 non-null      object
#  6   stage_3                                1 non-null      object
#  7   Tempo dos Incubados no Processo        11 non-null     object
#  8   select_by_projects                     7 non-null      object
#  9   select_by_ideias                       5 non-null      object
#  10  select_by_others                       1 non-null      object
#  11  Total de Incubados                     11 non-null     object
#  12  Atuais Incubados                       11 non-null     object
#  13  Acompanhamento dos Incubados?          11 non-null     object
#  14  Suporte Financeiro?                    11 non-null     object
#  15  Parcerias com elementos de Apoio?      11 non-null     object
#  16  Parcerias extendem para os Incubados?  11 non-null     object
#  17  Promove Interação entre Incubados?     11 non-null     object
#  18  handicap_management_knw                4 non-null      object
#  19  handicap_management_exp                7 non-null      object
#  20  handicap_technical_knw                 5 non-null      object
#  21  handicap_entrepeneur_knw               2 non-null      object
#  22  Competencias Técnicas?                 11 non-null     object
#  23  manag_knw_1                            11 non-null     object
#  24  manag_knw_2                            8 non-null      object
#  25  manag_knw_3                            6 non-null      object
#  26  manag_knw_4                            4 non-null      object
#  27  manag_knw_5                            3 non-null      object
#  28  manag_knw_6                            2 non-null      object
#  29  Transfere Conhecimento?                11 non-null     object
#  30  knw_transfer_tools_1                   11 non-null     object
#  31  knw_transfer_tools_2                   8 non-null      object
#  32  knw_transfer_tools_3                   3 non-null      object
#  33  Vínculo Empresarial                    11 non-null     bool
#  34  Vínculo Social                         11 non-null     bool
#  35  Vínculo Governamental                  11 non-null     bool
#  36  Outros Vínculos                        11 non-null     bool
# dtypes: bool(4), object(33)
# memory usage: 3.0+ KB

# %%
#da lista de colunas vemos que sao as 18-23, 6 
subset = incubadoras_updated.iloc[:,4:7]
subset
# Out:
#            stage_1    stage_2        stage_3
# ID
# 1        Incubação        NaN            NaN
# 2   Pré-incubação   Incubação            NaN
# 3        Incubação        NaN            NaN
# 4   Pré-incubação         NaN            NaN
# 5        Incubação        NaN            NaN
# 6   Pré-incubação         NaN            NaN
# 7   Pré-incubação   Incubação            NaN
# 8   Pré-incubação   Incubação            NaN
# 9        Incubação        NaN            NaN
# 10       Incubação        NaN            NaN
# 11  Pré-incubação   Incubação  Pós-incubação

# %%
subset['stage_1'].unique() 
subset['stage_3'].unique()
criteria_list = ['Incubação', 'Pré-incubação ', 'Pós-incubação']

# %%
criteria_list
# Out:
# ['Incubação', 'Pré-incubação ', 'Pós-incubação']

# %%
results = transpose_values(criteria_list,subset)
results
# Out:
#     Incubação  Pré-incubação   Pós-incubação
# ID
# 1        True           False          False
# 2        True            True          False
# 3        True           False          False
# 4       False            True          False
# 5        True           False          False
# 6       False            True          False
# 7        True            True          False
# 8        True            True          False
# 9        True           False          False
# 10       True           False          False
# 11       True            True           True

# %%
sufix = ['Incubação', 'Pré-incubação ', 'Pós-incubação']

# %%
#vamos juntar os resultados ao nosso dataset e eliminar as colunas antigas deste subset
incubadoras_updated = pd.concat([incubadoras_updated, results], axis=1 )

# %%
incubadoras_updated.drop(subset.columns, axis=1,inplace=True)

# %%
plt.figure(figsize=(15,5))
sns.heatmap(incubadoras_updated.notnull(), linewidths=1, cbar=False)
# Out:
# <AxesSubplot:ylabel='ID'>

# %% [markdown]
# #### Colunas da Selecção de Empresas

# %%
incubadoras_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 1 to 11
# Data columns (total 37 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Nome da Incubadora                     11 non-null     object
#  1   Formação do Gestor                     11 non-null     object
#  2   Longevidade do Gestor                  11 non-null     object
#  3   Tipo de Incubadora                     11 non-null     object
#  4   Tempo dos Incubados no Processo        11 non-null     object
#  5   select_by_projects                     7 non-null      object
#  6   select_by_ideias                       5 non-null      object
#  7   select_by_others                       1 non-null      object
#  8   Total de Incubados                     11 non-null     object
#  9   Atuais Incubados                       11 non-null     object
#  10  Acompanhamento dos Incubados?          11 non-null     object
#  11  Suporte Financeiro?                    11 non-null     object
#  12  Parcerias com elementos de Apoio?      11 non-null     object
#  13  Parcerias extendem para os Incubados?  11 non-null     object
#  14  Promove Interação entre Incubados?     11 non-null     object
#  15  handicap_management_knw                4 non-null      object
#  16  handicap_management_exp                7 non-null      object
#  17  handicap_technical_knw                 5 non-null      object
#  18  handicap_entrepeneur_knw               2 non-null      object
#  19  Competencias Técnicas?                 11 non-null     object
#  20  manag_knw_1                            11 non-null     object
#  21  manag_knw_2                            8 non-null      object
#  22  manag_knw_3                            6 non-null      object
#  23  manag_knw_4                            4 non-null      object
#  24  manag_knw_5                            3 non-null      object
#  25  manag_knw_6                            2 non-null      object
#  26  Transfere Conhecimento?                11 non-null     object
#  27  knw_transfer_tools_1                   11 non-null     object
#  28  knw_transfer_tools_2                   8 non-null      object
#  29  knw_transfer_tools_3                   3 non-null      object
#  30  Vínculo Empresarial                    11 non-null     bool
#  31  Vínculo Social                         11 non-null     bool
#  32  Vínculo Governamental                  11 non-null     bool
#  33  Outros Vínculos                        11 non-null     bool
#  34  Incubação                              11 non-null     bool
#  35  Pré-incubação                          11 non-null     bool
#  36  Pós-incubação                          11 non-null     bool
# dtypes: bool(7), object(30)
# memory usage: 2.7+ KB

# %%
#da lista de colunas acima identificam-se as colinas 18:21
subset = incubadoras_updated.iloc[:,5:8]
subset
# Out:
#    select_by_projects select_by_ideias select_by_others
# ID
# 1                True             True              NaN
# 2                True             True              NaN
# 3                 NaN             True              NaN
# 4                True              NaN              NaN
# 5                 NaN              NaN             True
# 6                 NaN             True              NaN
# 7                True              NaN              NaN
# 8                True              NaN              NaN
# 9                True              NaN              NaN
# 10               True              NaN              NaN
# 11                NaN             True              NaN

# %%
results = subset.fillna(False)
results.rename(columns = {'select_by_projects':'Projetos', 'select_by_ideias':'Ideias', 'select_by_others':'Outros'},inplace=True)

# %%
#juntar o resultado ao dataset original e apagar as colunas anteriores
incubadoras_updated = pd.concat([incubadoras_updated, results], axis=1 )
incubadoras_updated.drop(subset.columns, axis=1,inplace=True)

# %%
plt.figure(figsize=(15,5))
sns.heatmap(incubadoras_updated.notnull(), linewidths=1, cbar=False)
# Out:
# <AxesSubplot:ylabel='ID'>

# %% [markdown]
# #### Colunas das CARÊNCIAS das empresas incubads (handicaps)

# %%
incubadoras_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 1 to 11
# Data columns (total 37 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Nome da Incubadora                     11 non-null     object
#  1   Formação do Gestor                     11 non-null     object
#  2   Longevidade do Gestor                  11 non-null     object
#  3   Tipo de Incubadora                     11 non-null     object
#  4   Tempo dos Incubados no Processo        11 non-null     object
#  5   Total de Incubados                     11 non-null     object
#  6   Atuais Incubados                       11 non-null     object
#  7   Acompanhamento dos Incubados?          11 non-null     object
#  8   Suporte Financeiro?                    11 non-null     object
#  9   Parcerias com elementos de Apoio?      11 non-null     object
#  10  Parcerias extendem para os Incubados?  11 non-null     object
#  11  Promove Interação entre Incubados?     11 non-null     object
#  12  handicap_management_knw                4 non-null      object
#  13  handicap_management_exp                7 non-null      object
#  14  handicap_technical_knw                 5 non-null      object
#  15  handicap_entrepeneur_knw               2 non-null      object
#  16  Competencias Técnicas?                 11 non-null     object
#  17  manag_knw_1                            11 non-null     object
#  18  manag_knw_2                            8 non-null      object
#  19  manag_knw_3                            6 non-null      object
#  20  manag_knw_4                            4 non-null      object
#  21  manag_knw_5                            3 non-null      object
#  22  manag_knw_6                            2 non-null      object
#  23  Transfere Conhecimento?                11 non-null     object
#  24  knw_transfer_tools_1                   11 non-null     object
#  25  knw_transfer_tools_2                   8 non-null      object
#  26  knw_transfer_tools_3                   3 non-null      object
#  27  Vínculo Empresarial                    11 non-null     bool
#  28  Vínculo Social                         11 non-null     bool
#  29  Vínculo Governamental                  11 non-null     bool
#  30  Outros Vínculos                        11 non-null     bool
#  31  Incubação                              11 non-null     bool
#  32  Pré-incubação                          11 non-null     bool
#  33  Pós-incubação                          11 non-null     bool
#  34  Projetos                               11 non-null     bool
#  35  Ideias                                 11 non-null     bool
#  36  Outros                                 11 non-null     bool
# dtypes: bool(10), object(27)
# memory usage: 2.5+ KB

# %%
#da lista de colunas acima identificam-se as colinas 14:18
subset = incubadoras_updated.iloc[:,12:16]
subset.fillna(False, inplace=True)

# %%
result = subset.copy()

# %%
#renomear as colunas para a convençao utilizada
column_keys = {'handicap_management_knw':'Conhecimentos de Gestão', 
                'handicap_management_exp':'Experiencia de Gestão',
                'handicap_technical_knw':'Conhecimentos Técnicos', 
                'handicap_entrepeneur_knw':'Conhecimentos de Empreendedorismo'}

# %%
result.rename(columns =column_keys ,inplace=True)

# %%
#juntar o resultado ao dataset original e apagar as colunas anteriores
incubadoras_updated = pd.concat([incubadoras_updated, result], axis=1 )
incubadoras_updated.drop(subset.columns, axis=1,inplace=True)

# %%
plt.figure(figsize=(15,5))
sns.heatmap(incubadoras_updated.notnull(), linewidths=1, cbar=False)
# Out:
# <AxesSubplot:ylabel='ID'>

# %% [markdown]
# #### Colunas do 'Conhecimento de Gestão'

# %%
incubadoras_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 1 to 11
# Data columns (total 37 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Nome da Incubadora                     11 non-null     object
#  1   Formação do Gestor                     11 non-null     object
#  2   Longevidade do Gestor                  11 non-null     object
#  3   Tipo de Incubadora                     11 non-null     object
#  4   Tempo dos Incubados no Processo        11 non-null     object
#  5   Total de Incubados                     11 non-null     object
#  6   Atuais Incubados                       11 non-null     object
#  7   Acompanhamento dos Incubados?          11 non-null     object
#  8   Suporte Financeiro?                    11 non-null     object
#  9   Parcerias com elementos de Apoio?      11 non-null     object
#  10  Parcerias extendem para os Incubados?  11 non-null     object
#  11  Promove Interação entre Incubados?     11 non-null     object
#  12  Competencias Técnicas?                 11 non-null     object
#  13  manag_knw_1                            11 non-null     object
#  14  manag_knw_2                            8 non-null      object
#  15  manag_knw_3                            6 non-null      object
#  16  manag_knw_4                            4 non-null      object
#  17  manag_knw_5                            3 non-null      object
#  18  manag_knw_6                            2 non-null      object
#  19  Transfere Conhecimento?                11 non-null     object
#  20  knw_transfer_tools_1                   11 non-null     object
#  21  knw_transfer_tools_2                   8 non-null      object
#  22  knw_transfer_tools_3                   3 non-null      object
#  23  Vínculo Empresarial                    11 non-null     bool
#  24  Vínculo Social                         11 non-null     bool
#  25  Vínculo Governamental                  11 non-null     bool
#  26  Outros Vínculos                        11 non-null     bool
#  27  Incubação                              11 non-null     bool
#  28  Pré-incubação                          11 non-null     bool
#  29  Pós-incubação                          11 non-null     bool
#  30  Projetos                               11 non-null     bool
#  31  Ideias                                 11 non-null     bool
#  32  Outros                                 11 non-null     bool
#  33  Conhecimentos de Gestão                11 non-null     bool
#  34  Experiencia de Gestão                  11 non-null     bool
#  35  Conhecimentos Técnicos                 11 non-null     bool
#  36  Conhecimentos de Empreendedorismo      11 non-null     bool
# dtypes: bool(14), object(23)
# memory usage: 2.2+ KB

# %%
subset = incubadoras_updated.iloc[:,13:19] # slice of the dataframe to convert to a new set of columns
subset
# Out:
#                                manag_knw_1  \
# ID
# 1                                Marketing
# 2                         Recursos Humanos
# 3                                Marketing
# 4                         Recursos Humanos
# 5   Comercialização de produtos e serviços
# 6                     Assistência jurídica
# 7                                Marketing
# 8                         Recursos Humanos
# 9                                Marketing
# 10                    Assistência jurídica
# 11                        Recursos Humanos
#
#                                manag_knw_2  \
# ID
# 1   Comercialização de produtos e serviços
# 2                                Marketing
# 3   Comercialização de produtos e serviços
# 4                                Marketing
# 5                                      NaN
# 6                                      NaN
# 7                     Assistência contábil
# 8                                Marketing
# 9   Comercialização de produtos e serviços
# 10                                     NaN
# 11                               Marketing
#
#                                manag_knw_3  \
# ID
# 1                                      NaN
# 2                     Assistência contábil
# 3                        Gestão Financeira
# 4   Comercialização de produtos e serviços
# 5                                      NaN
# 6                                      NaN
# 7                        Gestão Financeira
# 8                     Assistência jurídica
# 9                                      NaN
# 10                                     NaN
# 11                    Assistência jurídica
#
#                                manag_knw_4  \
# ID
# 1                                      NaN
# 2   Comercialização de produtos e serviços
# 3                                      NaN
# 4                        Gestão Financeira
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                     Assistência contábil
# 9                                      NaN
# 10                                     NaN
# 11                    Assistência contábil
#
#                                manag_knw_5        manag_knw_6
# ID
# 1                                      NaN                NaN
# 2                        Gestão Financeira                NaN
# 3                                      NaN                NaN
# 4                                      NaN                NaN
# 5                                      NaN                NaN
# 6                                      NaN                NaN
# 7                                      NaN                NaN
# 8   Comercialização de produtos e serviços  Gestão Financeira
# 9                                      NaN                NaN
# 10                                     NaN                NaN
# 11  Comercialização de produtos e serviços  Gestão Financeira

# %%
subset.columns
# Out:
# Index(['manag_knw_1', 'manag_knw_2', 'manag_knw_3', 'manag_knw_4',
#        'manag_knw_5', 'manag_knw_6'],
#       dtype='object')

# %%
#com base nos valores das respostas, podemos construir a lista de todas as atividades que foram respondidas pelo menos uma vez
criteria_list = ['Marketing', 
                 'Recursos Humanos',
                 'Comercialização de produtos e serviços', 
                 'Assistência jurídica',
                 'Assistência contábil',
                 'Gestão Financeira']

# %%
results = transpose_values(criteria_list,subset)
results.sum(axis=1).value_counts()
results.fillna(False)
# Out:
#     Marketing  Recursos Humanos  Comercialização de produtos e serviços  \
# ID
# 1        True             False                                    True
# 2        True              True                                    True
# 3        True             False                                    True
# 4        True              True                                    True
# 5       False             False                                    True
# 6       False             False                                   False
# 7        True             False                                   False
# 8        True              True                                    True
# 9        True             False                                    True
# 10      False             False                                   False
# 11       True              True                                    True
#
#     Assistência jurídica  Assistência contábil  Gestão Financeira
# ID
# 1                  False                 False              False
# 2                  False                  True               True
# 3                  False                 False               True
# 4                  False                 False               True
# 5                  False                 False              False
# 6                   True                 False              False
# 7                  False                  True               True
# 8                   True                  True               True
# 9                  False                 False              False
# 10                  True                 False              False
# 11                  True                  True               True

# %%
#Eliminamos as antigas colunas que já não são necessárias e adicionamos os resultados 
incubadoras_updated = pd.concat([incubadoras_updated,results], axis=1)
incubadoras_updated.drop(subset.columns, axis=1, inplace=True)

# %%
# alterar nome das colunas criadas
replace_keys= {'Instituições Empresariais':'Vínculo Empresarial',
                 'Instituições Sociais':'Vínculo Social',
                 'Instituições Governamentais':'Vínculo Governamental', 
                 'Outras Instituições':'Outros Vínculos'}
incubadoras_updated.rename(columns=replace_keys, inplace=True)

# %%
plt.figure(figsize=(15,5))
sns.heatmap(incubadoras_updated.notnull(), linewidths=1, cbar=False)
# Out:
# <AxesSubplot:ylabel='ID'>

# %% [markdown]
# #### Colunas das ferramentas de transferencia de conhecimento

# %%
incubadoras_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 1 to 11
# Data columns (total 37 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Nome da Incubadora                      11 non-null     object
#  1   Formação do Gestor                      11 non-null     object
#  2   Longevidade do Gestor                   11 non-null     object
#  3   Tipo de Incubadora                      11 non-null     object
#  4   Tempo dos Incubados no Processo         11 non-null     object
#  5   Total de Incubados                      11 non-null     object
#  6   Atuais Incubados                        11 non-null     object
#  7   Acompanhamento dos Incubados?           11 non-null     object
#  8   Suporte Financeiro?                     11 non-null     object
#  9   Parcerias com elementos de Apoio?       11 non-null     object
#  10  Parcerias extendem para os Incubados?   11 non-null     object
#  11  Promove Interação entre Incubados?      11 non-null     object
#  12  Competencias Técnicas?                  11 non-null     object
#  13  Transfere Conhecimento?                 11 non-null     object
#  14  knw_transfer_tools_1                    11 non-null     object
#  15  knw_transfer_tools_2                    8 non-null      object
#  16  knw_transfer_tools_3                    3 non-null      object
#  17  Vínculo Empresarial                     11 non-null     bool
#  18  Vínculo Social                          11 non-null     bool
#  19  Vínculo Governamental                   11 non-null     bool
#  20  Outros Vínculos                         11 non-null     bool
#  21  Incubação                               11 non-null     bool
#  22  Pré-incubação                           11 non-null     bool
#  23  Pós-incubação                           11 non-null     bool
#  24  Projetos                                11 non-null     bool
#  25  Ideias                                  11 non-null     bool
#  26  Outros                                  11 non-null     bool
#  27  Conhecimentos de Gestão                 11 non-null     bool
#  28  Experiencia de Gestão                   11 non-null     bool
#  29  Conhecimentos Técnicos                  11 non-null     bool
#  30  Conhecimentos de Empreendedorismo       11 non-null     bool
#  31  Marketing                               11 non-null     bool
#  32  Recursos Humanos                        11 non-null     bool
#  33  Comercialização de produtos e serviços  11 non-null     bool
#  34  Assistência jurídica                    11 non-null     bool
#  35  Assistência contábil                    11 non-null     bool
#  36  Gestão Financeira                       11 non-null     bool
# dtypes: bool(20), object(17)
# memory usage: 1.8+ KB

# %%
subset = incubadoras_updated.iloc[:,14:17] # slice of the dataframe to convert to a new set of columns
subset
# Out:
#                   knw_transfer_tools_1                knw_transfer_tools_2  \
# ID
# 1                  Lista de discussão                             Reuniões
# 2                             Manuais   Formação e cursos e/ou tecnológico
# 3   Formação e cursos e/ou tecnológico                            Reuniões
# 4                             Manuais   Formação e cursos e/ou tecnológico
# 5                             Reuniões                                 NaN
# 6                             Manuais                                  NaN
# 7   Formação e cursos e/ou tecnológico                                 NaN
# 8                             Manuais   Formação e cursos e/ou tecnológico
# 9                             Reuniões                              Fóruns
# 10  Formação e cursos e/ou tecnológico                            Reuniões
# 11  Formação e cursos e/ou tecnológico                            Reuniões
#
#    knw_transfer_tools_3
# ID
# 1                   NaN
# 2              Reuniões
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8              Reuniões
# 9                   NaN
# 10                  NaN
# 11               Fóruns

# %%
subset['knw_transfer_tools_1'].unique()
# Out:
# array(['Lista de discussão ', 'Manuais ',
#        'Formação e cursos e/ou tecnológico', 'Reuniões'], dtype=object)

# %%
#com base nos valores das respostas, podemos construir a lista de todas as atividades que foram respondidas pelo menos uma vez
criteria_list = ['Lista de discussão ', 'Manuais ',
       'Formação e cursos e/ou tecnológico', 'Reuniões']

# %%
results = transpose_values(criteria_list,subset)
results.fillna(False)
results
# Out:
#     Lista de discussão   Manuais   Formação e cursos e/ou tecnológico  \
# ID
# 1                  True     False                               False
# 2                 False      True                                True
# 3                 False     False                                True
# 4                 False      True                                True
# 5                 False     False                               False
# 6                 False      True                               False
# 7                 False     False                                True
# 8                 False      True                                True
# 9                 False     False                               False
# 10                False     False                                True
# 11                False     False                                True
#
#     Reuniões
# ID
# 1       True
# 2       True
# 3       True
# 4      False
# 5       True
# 6      False
# 7      False
# 8       True
# 9       True
# 10      True
# 11      True

# %%
incubadoras_updated
# Out:
#     Nome da Incubadora                      Formação do Gestor  \
# ID
# 1        CLESE Cabinda              4º de ensino de Matemática
# 2        CLESE Malange                  Psicologia Educacional
# 3         CLESE Huambo                               Agronomia
# 4           CLESE Uíge                  Contabilidade e Gestão
# 5          CLESE Dundo                      Gestão e Marketing
# 6         CLESE Moxico           Contabilidade e Administração
# 7          CLESE Sumbe                             Informática
# 8                 IEMP                         Economia/Gestão
# 9       CLESE Benguela  Gestão Estratégica de Recursos Humanos
# 10  CLESE Kuanza Norte                           Contabilidade
# 11         CLESE Huíla                  Psicologia Educacional
#
#    Longevidade do Gestor                     Tipo de Incubadora  \
# ID
# 1                 7 anos       Incubadoras de Base Tecnológica
# 2                  1 ano                    Incubadoras Mistas
# 3                 9 anos                    Incubadoras Mistas
# 4                 4 anos                    Incubadoras Mistas
# 5                 4 anos                    Incubadoras Mistas
# 6                 9 anos                    Incubadoras Mistas
# 7                 8 anos       Incubadoras de Base Tecnológica
# 8                 9 anos                    Incubadoras Mistas
# 9                 6 anos                    Incubadoras Mistas
# 10                2 anos  Incubadoras de Sectores Tradicionais
# 11                5 anos                    Incubadoras Mistas
#
#    Tempo dos Incubados no Processo Total de Incubados Atuais Incubados  \
# ID
# 1        Entre 12meses e 24 meses         Menos de 10      Menos de 10
# 2               Entre 6 a 12 meses      Entre 10 e 20      Menos de 10
# 3              Entre 24 e 36 meses      Entre 40 e 50    Entre 10 e 20
# 4                     Até 6 meses       Entre 40 e 50      Menos de 10
# 5        Entre 12meses e 24 meses         Menos de 10      Menos de 10
# 6               Entre 6 a 12 meses      Entre 20 e 30      Menos de 10
# 7               Entre 6 a 12 meses      Entre 10 e 20      Menos de 10
# 8        Entre 12meses e 24 meses       Entre 10 e 20    Entre 20 e 30
# 9               Entre 6 a 12 meses      Entre 10 e 20      Menos de 10
# 10       Entre 12meses e 24 meses       Entre 10 e 20      Menos de 10
# 11             Entre 24 e 36 meses      Entre 40 e 50    Entre 10 e 20
#
#    Acompanhamento dos Incubados? Suporte Financeiro?  \
# ID
# 1                            Não                 Não
# 2                           Sim                  Não
# 3                           Sim                  Não
# 4                           Sim                 Sim
# 5                           Sim                  Não
# 6                           Sim                  Não
# 7                           Sim                 Sim
# 8                            Não                 Não
# 9                           Sim                  Não
# 10                          Sim                  Não
# 11                          Sim                  Não
#
#    Parcerias com elementos de Apoio? Parcerias extendem para os Incubados?  \
# ID
# 1                               Sim                                   Sim
# 2                               Sim                                   Sim
# 3                               Sim                                   Sim
# 4                               Sim                                   Sim
# 5                                Não                                   Não
# 6                               Sim                                   Sim
# 7                               Sim                                    Não
# 8                               Sim                                    Não
# 9                                Não                                   Não
# 10                              Sim                                   Sim
# 11                               Não                                   Não
#
#    Promove Interação entre Incubados? Competencias Técnicas?  \
# ID
# 1                                 Não                    Não
# 2                                Sim                    Sim
# 3                                Sim                     Não
# 4                                Sim                    Sim
# 5                                Sim                    Sim
# 6                                Sim                    Sim
# 7                                Sim                    Sim
# 8                                Sim                     Não
# 9                                 Não                   Sim
# 10                               Sim                    Sim
# 11                               Sim                    Sim
#
#    Transfere Conhecimento?                knw_transfer_tools_1  \
# ID
# 1                     Sim                  Lista de discussão
# 2                     Sim                             Manuais
# 3                     Sim   Formação e cursos e/ou tecnológico
# 4                     Sim                             Manuais
# 5                     Sim                             Reuniões
# 6                     Sim                             Manuais
# 7                     Sim   Formação e cursos e/ou tecnológico
# 8                      Não                            Manuais
# 9                     Sim                             Reuniões
# 10                    Sim   Formação e cursos e/ou tecnológico
# 11                    Sim   Formação e cursos e/ou tecnológico
#
#                   knw_transfer_tools_2 knw_transfer_tools_3  \
# ID
# 1                             Reuniões                  NaN
# 2   Formação e cursos e/ou tecnológico             Reuniões
# 3                             Reuniões                  NaN
# 4   Formação e cursos e/ou tecnológico                  NaN
# 5                                  NaN                  NaN
# 6                                  NaN                  NaN
# 7                                  NaN                  NaN
# 8   Formação e cursos e/ou tecnológico             Reuniões
# 9                               Fóruns                  NaN
# 10                            Reuniões                  NaN
# 11                            Reuniões               Fóruns
#
#     Vínculo Empresarial  Vínculo Social  Vínculo Governamental  \
# ID
# 1                  True           False                  False
# 2                 False            True                  False
# 3                 False           False                   True
# 4                 False            True                   True
# 5                  True           False                  False
# 6                 False           False                  False
# 7                 False           False                   True
# 8                 False           False                   True
# 9                  True           False                  False
# 10                 True           False                  False
# 11                False           False                   True
#
#     Outros Vínculos  Incubação  Pré-incubação   Pós-incubação  Projetos  \
# ID
# 1             False       True           False          False      True
# 2             False       True            True          False      True
# 3             False       True           False          False     False
# 4             False      False            True          False      True
# 5             False       True           False          False     False
# 6              True      False            True          False     False
# 7             False       True            True          False      True
# 8              True       True            True          False      True
# 9             False       True           False          False      True
# 10            False       True           False          False      True
# 11            False       True            True           True     False
#
#     Ideias  Outros  Conhecimentos de Gestão  Experiencia de Gestão  \
# ID
# 1     True   False                    False                  False
# 2     True   False                     True                   True
# 3     True   False                    False                  False
# 4    False   False                    False                   True
# 5    False    True                    False                   True
# 6     True   False                     True                  False
# 7    False   False                     True                  False
# 8    False   False                     True                   True
# 9    False   False                    False                   True
# 10   False   False                    False                   True
# 11    True   False                    False                   True
#
#     Conhecimentos Técnicos  Conhecimentos de Empreendedorismo  Marketing  \
# ID
# 1                     True                              False       True
# 2                     True                              False       True
# 3                     True                              False       True
# 4                    False                              False       True
# 5                    False                              False      False
# 6                    False                              False      False
# 7                    False                               True       True
# 8                     True                               True       True
# 9                     True                              False       True
# 10                   False                              False      False
# 11                   False                              False       True
#
#     Recursos Humanos  Comercialização de produtos e serviços  \
# ID
# 1              False                                    True
# 2               True                                    True
# 3              False                                    True
# 4               True                                    True
# 5              False                                    True
# 6              False                                   False
# 7              False                                   False
# 8               True                                    True
# 9              False                                    True
# 10             False                                   False
# 11              True                                    True
#
#     Assistência jurídica  Assistência contábil  Gestão Financeira
# ID
# 1                  False                 False              False
# 2                  False                  True               True
# 3                  False                 False               True
# 4                  False                 False               True
# 5                  False                 False              False
# 6                   True                 False              False
# 7                  False                  True               True
# 8                   True                  True               True
# 9                  False                 False              False
# 10                  True                 False              False
# 11                  True                  True               True

# %%
#Eliminamos as antigas colunas que já não são necessárias e adicionamos os resultados 
incubadoras_updated = pd.concat([incubadoras_updated,results], axis=1)
incubadoras_updated.drop(subset.columns, axis=1, inplace=True)

# %%
plt.figure(figsize=(15,5))
sns.heatmap(incubadoras_updated.notnull(), linewidths=1, cbar=False)
# Out:
# <AxesSubplot:ylabel='ID'>

# %%
incubadoras_updated
# Out:
#     Nome da Incubadora                      Formação do Gestor  \
# ID
# 1        CLESE Cabinda              4º de ensino de Matemática
# 2        CLESE Malange                  Psicologia Educacional
# 3         CLESE Huambo                               Agronomia
# 4           CLESE Uíge                  Contabilidade e Gestão
# 5          CLESE Dundo                      Gestão e Marketing
# 6         CLESE Moxico           Contabilidade e Administração
# 7          CLESE Sumbe                             Informática
# 8                 IEMP                         Economia/Gestão
# 9       CLESE Benguela  Gestão Estratégica de Recursos Humanos
# 10  CLESE Kuanza Norte                           Contabilidade
# 11         CLESE Huíla                  Psicologia Educacional
#
#    Longevidade do Gestor                     Tipo de Incubadora  \
# ID
# 1                 7 anos       Incubadoras de Base Tecnológica
# 2                  1 ano                    Incubadoras Mistas
# 3                 9 anos                    Incubadoras Mistas
# 4                 4 anos                    Incubadoras Mistas
# 5                 4 anos                    Incubadoras Mistas
# 6                 9 anos                    Incubadoras Mistas
# 7                 8 anos       Incubadoras de Base Tecnológica
# 8                 9 anos                    Incubadoras Mistas
# 9                 6 anos                    Incubadoras Mistas
# 10                2 anos  Incubadoras de Sectores Tradicionais
# 11                5 anos                    Incubadoras Mistas
#
#    Tempo dos Incubados no Processo Total de Incubados Atuais Incubados  \
# ID
# 1        Entre 12meses e 24 meses         Menos de 10      Menos de 10
# 2               Entre 6 a 12 meses      Entre 10 e 20      Menos de 10
# 3              Entre 24 e 36 meses      Entre 40 e 50    Entre 10 e 20
# 4                     Até 6 meses       Entre 40 e 50      Menos de 10
# 5        Entre 12meses e 24 meses         Menos de 10      Menos de 10
# 6               Entre 6 a 12 meses      Entre 20 e 30      Menos de 10
# 7               Entre 6 a 12 meses      Entre 10 e 20      Menos de 10
# 8        Entre 12meses e 24 meses       Entre 10 e 20    Entre 20 e 30
# 9               Entre 6 a 12 meses      Entre 10 e 20      Menos de 10
# 10       Entre 12meses e 24 meses       Entre 10 e 20      Menos de 10
# 11             Entre 24 e 36 meses      Entre 40 e 50    Entre 10 e 20
#
#    Acompanhamento dos Incubados? Suporte Financeiro?  \
# ID
# 1                            Não                 Não
# 2                           Sim                  Não
# 3                           Sim                  Não
# 4                           Sim                 Sim
# 5                           Sim                  Não
# 6                           Sim                  Não
# 7                           Sim                 Sim
# 8                            Não                 Não
# 9                           Sim                  Não
# 10                          Sim                  Não
# 11                          Sim                  Não
#
#    Parcerias com elementos de Apoio? Parcerias extendem para os Incubados?  \
# ID
# 1                               Sim                                   Sim
# 2                               Sim                                   Sim
# 3                               Sim                                   Sim
# 4                               Sim                                   Sim
# 5                                Não                                   Não
# 6                               Sim                                   Sim
# 7                               Sim                                    Não
# 8                               Sim                                    Não
# 9                                Não                                   Não
# 10                              Sim                                   Sim
# 11                               Não                                   Não
#
#    Promove Interação entre Incubados? Competencias Técnicas?  \
# ID
# 1                                 Não                    Não
# 2                                Sim                    Sim
# 3                                Sim                     Não
# 4                                Sim                    Sim
# 5                                Sim                    Sim
# 6                                Sim                    Sim
# 7                                Sim                    Sim
# 8                                Sim                     Não
# 9                                 Não                   Sim
# 10                               Sim                    Sim
# 11                               Sim                    Sim
#
#    Transfere Conhecimento?  Vínculo Empresarial  Vínculo Social  \
# ID
# 1                     Sim                  True           False
# 2                     Sim                 False            True
# 3                     Sim                 False           False
# 4                     Sim                 False            True
# 5                     Sim                  True           False
# 6                     Sim                 False           False
# 7                     Sim                 False           False
# 8                      Não                False           False
# 9                     Sim                  True           False
# 10                    Sim                  True           False
# 11                    Sim                 False           False
#
#     Vínculo Governamental  Outros Vínculos  Incubação  Pré-incubação   \
# ID
# 1                   False            False       True           False
# 2                   False            False       True            True
# 3                    True            False       True           False
# 4                    True            False      False            True
# 5                   False            False       True           False
# 6                   False             True      False            True
# 7                    True            False       True            True
# 8                    True             True       True            True
# 9                   False            False       True           False
# 10                  False            False       True           False
# 11                   True            False       True            True
#
#     Pós-incubação  Projetos  Ideias  Outros  Conhecimentos de Gestão  \
# ID
# 1           False      True    True   False                    False
# 2           False      True    True   False                     True
# 3           False     False    True   False                    False
# 4           False      True   False   False                    False
# 5           False     False   False    True                    False
# 6           False     False    True   False                     True
# 7           False      True   False   False                     True
# 8           False      True   False   False                     True
# 9           False      True   False   False                    False
# 10          False      True   False   False                    False
# 11           True     False    True   False                    False
#
#     Experiencia de Gestão  Conhecimentos Técnicos  \
# ID
# 1                   False                    True
# 2                    True                    True
# 3                   False                    True
# 4                    True                   False
# 5                    True                   False
# 6                   False                   False
# 7                   False                   False
# 8                    True                    True
# 9                    True                    True
# 10                   True                   False
# 11                   True                   False
#
#     Conhecimentos de Empreendedorismo  Marketing  Recursos Humanos  \
# ID
# 1                               False       True             False
# 2                               False       True              True
# 3                               False       True             False
# 4                               False       True              True
# 5                               False      False             False
# 6                               False      False             False
# 7                                True       True             False
# 8                                True       True              True
# 9                               False       True             False
# 10                              False      False             False
# 11                              False       True              True
#
#     Comercialização de produtos e serviços  Assistência jurídica  \
# ID
# 1                                     True                 False
# 2                                     True                 False
# 3                                     True                 False
# 4                                     True                 False
# 5                                     True                 False
# 6                                    False                  True
# 7                                    False                 False
# 8                                     True                  True
# 9                                     True                 False
# 10                                   False                  True
# 11                                    True                  True
#
#     Assistência contábil  Gestão Financeira  Lista de discussão   Manuais   \
# ID
# 1                  False              False                 True     False
# 2                   True               True                False      True
# 3                  False               True                False     False
# 4                  False               True                False      True
# 5                  False              False                False     False
# 6                  False              False                False      True
# 7                   True               True                False     False
# 8                   True               True                False      True
# 9                  False              False                False     False
# 10                 False              False                False     False
# 11                  True               True                False     False
#
#     Formação e cursos e/ou tecnológico  Reuniões
# ID
# 1                                False      True
# 2                                 True      True
# 3                                 True      True
# 4                                 True     False
# 5                                False      True
# 6                                False     False
# 7                                 True     False
# 8                                 True      True
# 9                                False      True
# 10                                True      True
# 11                                True      True

# %% [markdown]
# #### Simplificação das restantes colunas

# %% [markdown]
# A formaçao do gestor nao permite qualquer informaçao adicional, pelo que vamos remover para tornar o dataset paraa analise mais simples.

# %%
incubadoras_updated.drop(columns='Formação do Gestor', inplace=True)

# %%
# transformar a longevidade o gestor em tipo numerico
pattern = r"(?P<Years>\d)"
incubadoras_updated['Longevidade do Gestor'] = incubadoras_updated['Longevidade do Gestor'].str.extract(pattern)

# %%
incubadoras_updated['Longevidade do Gestor'] = incubadoras_updated['Longevidade do Gestor'].astype(int)

# %%
# tipo de incubador
incubadoras_updated['Tipo de Incubadora'] = incubadoras_updated['Tipo de Incubadora'].str.replace('Incubadoras','')
incubadoras_updated['Tipo de Incubadora'] = incubadoras_updated['Tipo de Incubadora'].str.replace('de','')

# %%
incubadoras_updated['Tipo de Incubadora'] = incubadoras_updated['Tipo de Incubadora'].str.strip()

# %%
incubadoras_updated['Tipo de Incubadora'].unique()
# Out:
# array(['Base Tecnológica', 'Mistas', 'Sectores Tradicionais'],
#       dtype=object)

# %%
incubadoras_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 1 to 11
# Data columns (total 37 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Nome da Incubadora                      11 non-null     object
#  1   Longevidade do Gestor                   11 non-null     int64
#  2   Tipo de Incubadora                      11 non-null     category
#  3   Tempo dos Incubados no Processo         11 non-null     category
#  4   Total de Incubados                      11 non-null     category
#  5   Atuais Incubados                        11 non-null     category
#  6   Acompanhamento dos Incubados?           11 non-null     bool
#  7   Suporte Financeiro?                     11 non-null     bool
#  8   Parcerias com elementos de Apoio?       11 non-null     bool
#  9   Parcerias extendem para os Incubados?   11 non-null     bool
#  10  Promove Interação entre Incubados?      11 non-null     bool
#  11  Competencias Técnicas?                  11 non-null     bool
#  12  Transfere Conhecimento?                 11 non-null     bool
#  13  Vínculo Empresarial                     11 non-null     bool
#  14  Vínculo Social                          11 non-null     bool
#  15  Vínculo Governamental                   11 non-null     bool
#  16  Outros Vínculos                         11 non-null     bool
#  17  Incubação                               11 non-null     bool
#  18  Pré-incubação                           11 non-null     bool
#  19  Pós-incubação                           11 non-null     bool
#  20  Projetos                                11 non-null     bool
#  21  Ideias                                  11 non-null     bool
#  22  Outros                                  11 non-null     bool
#  23  Conhecimentos de Gestão                 11 non-null     bool
#  24  Experiencia de Gestão                   11 non-null     bool
#  25  Conhecimentos Técnicos                  11 non-null     bool
#  26  Conhecimentos de Empreendedorismo       11 non-null     bool
#  27  Marketing                               11 non-null     bool
#  28  Recursos Humanos                        11 non-null     bool
#  29  Comercialização de produtos e serviços  11 non-null     bool
#  30  Assistência jurídica                    11 non-null     bool
#  31  Assistência contábil                    11 non-null     bool
#  32  Gestão Financeira                       11 non-null     bool
#  33  Lista de discussão                      11 non-null     bool
#  34  Manuais                                 11 non-null     bool
#  35  Formação e cursos e/ou tecnológico      11 non-null     bool
#  36  Reuniões                                11 non-null     bool
# dtypes: bool(31), category(4), int64(1), object(1)
# memory usage: 1.3+ KB

# %% [markdown]
# #### Mudança do tipo de coluna

# %%
incubadoras_updated[incubadoras_updated.columns[2:6]] = incubadoras_updated[incubadoras_updated.columns[2:6]].astype("category")

# %%
incubadoras_updated[incubadoras_updated.columns[6:13]]
# Out:
#     Acompanhamento dos Incubados?  Suporte Financeiro?  \
# ID
# 1                           False                False
# 2                            True                False
# 3                            True                False
# 4                            True                 True
# 5                            True                False
# 6                            True                False
# 7                            True                 True
# 8                           False                False
# 9                            True                False
# 10                           True                False
# 11                           True                False
#
#     Parcerias com elementos de Apoio?  Parcerias extendem para os Incubados?  \
# ID
# 1                                True                                   True
# 2                                True                                   True
# 3                                True                                   True
# 4                                True                                   True
# 5                               False                                  False
# 6                                True                                   True
# 7                                True                                  False
# 8                                True                                  False
# 9                               False                                  False
# 10                               True                                   True
# 11                              False                                  False
#
#     Promove Interação entre Incubados?  Competencias Técnicas?  \
# ID
# 1                                False                   False
# 2                                 True                    True
# 3                                 True                   False
# 4                                 True                    True
# 5                                 True                    True
# 6                                 True                    True
# 7                                 True                    True
# 8                                 True                   False
# 9                                False                    True
# 10                                True                    True
# 11                                True                    True
#
#     Transfere Conhecimento?
# ID
# 1                      True
# 2                      True
# 3                      True
# 4                      True
# 5                      True
# 6                      True
# 7                      True
# 8                     False
# 9                      True
# 10                     True
# 11                     True

# %%
bol_keys = {'Não':False,'Sim ':True}
incubadoras_updated[incubadoras_updated.columns[6:13]] = incubadoras_updated[incubadoras_updated.columns[6:13]].replace(bol_keys)

# %%
incubadoras_updated[incubadoras_updated.columns[6:13]]
# Out:
#     Acompanhamento dos Incubados?  Suporte Financeiro?  \
# ID
# 1                           False                False
# 2                            True                False
# 3                            True                False
# 4                            True                 True
# 5                            True                False
# 6                            True                False
# 7                            True                 True
# 8                           False                False
# 9                            True                False
# 10                           True                False
# 11                           True                False
#
#     Parcerias com elementos de Apoio?  Parcerias extendem para os Incubados?  \
# ID
# 1                                True                                   True
# 2                                True                                   True
# 3                                True                                   True
# 4                                True                                   True
# 5                               False                                  False
# 6                                True                                   True
# 7                                True                                  False
# 8                                True                                  False
# 9                               False                                  False
# 10                               True                                   True
# 11                              False                                  False
#
#     Promove Interação entre Incubados?  Competencias Técnicas?  \
# ID
# 1                                False                   False
# 2                                 True                    True
# 3                                 True                   False
# 4                                 True                    True
# 5                                 True                    True
# 6                                 True                    True
# 7                                 True                    True
# 8                                 True                   False
# 9                                False                    True
# 10                                True                    True
# 11                                True                    True
#
#     Transfere Conhecimento?
# ID
# 1                      True
# 2                      True
# 3                      True
# 4                      True
# 5                      True
# 6                      True
# 7                      True
# 8                     False
# 9                      True
# 10                     True
# 11                     True

# %% [markdown]
# ## Exportação da base de dados para CSV com Dtypes

# %% [markdown]
# ### Incubados

# %%
# exportar dtypes para dictionary
dtypes_incubados = {column:incubados_updated6[column].dtype.name for column in incubados_updated6.columns}

# %%
# gravar a nova base de dados em formato CSV - incubados
incubados_updated6.to_csv('./data_output/incubados.csv', sep=',')

# gravar types da nova base de dados em formato Json
import json
with open('./data_output/incubados_dtypes.json', 'w') as json_file:
    json.dump(dtypes_incubados, json_file)

# %% [markdown]
# ### Incubadoras

# %%
# exportar dtypes para dictionary
dtypes_incubadoras = {column:incubadoras_updated[column].dtype.name for column in incubadoras_updated.columns}

# %%
# gravar a nova base de dados em formato CSV - incubados
incubadoras_updated.to_csv('./data_output/incubadoras.csv', sep=',')

# gravar types da nova base de dados em formato Json
import json
with open('./data_output/incubadoras_dtypes.json', 'w') as json_file:
    json.dump(dtypes_incubadoras, json_file)

# %%
dtypes_incubadoras
# Out:
# {'Nome da Incubadora': 'object',
#  'Longevidade do Gestor': 'int64',
#  'Tipo de Incubadora': 'category',
#  'Tempo dos Incubados no Processo': 'category',
#  'Total de Incubados': 'category',
#  'Atuais Incubados': 'category',
#  'Acompanhamento dos Incubados?': 'bool',
#  'Suporte Financeiro?': 'bool',
#  'Parcerias com elementos de Apoio?': 'bool',
#  'Parcerias extendem para os Incubados?': 'bool',
#  'Promove Interação entre Incubados?': 'bool',
#  'Competencias Técnicas?': 'bool',
#  'Transfere Conhecimento?': 'bool',
#  'Vínculo Empresarial': 'bool',
#  'Vínculo Social': 'bool',
#  'Vínculo Governamental': 'bool',
#  'Outros Vínculos': 'bool',
#  'Incubação': 'bool',
#  'Pré-incubação ': 'bool',
#  'Pós-incubação': 'bool',
#  'Projetos': 'bool',
#  'Ideias': 'bool',
#  'Outros': 'bool',
#  'Conhecimentos de Gestão': 'bool',
#  'Experiencia de Gestão': 'bool',
#  'Conhecimentos Técnicos': 'bool',
#  'Conhecimentos de Empreendedorismo': 'bool',
#  'Marketing': 'bool',
#  'Recursos Humanos': 'bool',
#  'Comercialização de produtos e serviços': 'bool',
#  'Assistência jurídica': 'bool',
#  'Assistência contábil': 'bool',
#  'Gestão Financeira': 'bool',
#  'Lista de discussão ': 'bool',
#  'Manuais ': 'bool',
#  'Formação e cursos e/ou tecnológico': 'bool',
#  'Reuniões': 'bool'}
