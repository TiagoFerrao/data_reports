# %% [markdown]
# # <center> EMPREENDEDORISMO EM ANGOLA

# %% [markdown]
# ![angola.png](attachment:angola.png)
# # <center> PARTE 2: ANÁLISE E VISUALIZAÇÃO DOS DADOS
#
# Este relatório apresenta a caracterização possível das variáveis de interesse para os objectivos, através das estaticas descritivas simples, visualização mais adequada e breve análise.

# %% [markdown]
# <h1>ÍNDICE:<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#1.-INCUBADOS" data-toc-modified-id="1.-INCUBADOS-1">1. INCUBADOS</a></span></li><li><span><a href="#1.1.-CARACTERIZAÇÃO-GERAL-DA-BASE-DE-DADOS" data-toc-modified-id="1.1.-CARACTERIZAÇÃO-GERAL-DA-BASE-DE-DADOS-2">1.1. CARACTERIZAÇÃO GERAL DA BASE DE DADOS</a></span><ul class="toc-item"><li><span><a href="#1.2.-DADOS-DOS-EMPREENDORES" data-toc-modified-id="1.2.-DADOS-DOS-EMPREENDORES-2.1">1.2. DADOS DOS EMPREENDORES</a></span><ul class="toc-item"><li><span><a href="#1.2.1.-Idade-[p_age]" data-toc-modified-id="1.2.1.-Idade-[p_age]-2.1.1">1.2.1. Idade [p_age]</a></span></li><li><span><a href="#1.2.2.-Género-[p_gender]" data-toc-modified-id="1.2.2.-Género-[p_gender]-2.1.2">1.2.2. Género [p_gender]</a></span></li><li><span><a href="#1.2.3.-Nível-de-Escolaridade-[p_literacy]" data-toc-modified-id="1.2.3.-Nível-de-Escolaridade-[p_literacy]-2.1.3">1.2.3. Nível de Escolaridade [p_literacy]</a></span></li></ul></li></ul></li><li><span><a href="#1.3-CARACTERIZAÇÃO-DAS-EMPRESAS-INCUBADAS" data-toc-modified-id="1.3-CARACTERIZAÇÃO-DAS-EMPRESAS-INCUBADAS-3">1.3 CARACTERIZAÇÃO DAS EMPRESAS INCUBADAS</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#1.3.1.-Número-de-colaboradores-e-dimensao-da-empresa-[c_employees]--e--[c_size]" data-toc-modified-id="1.3.1.-Número-de-colaboradores-e-dimensao-da-empresa-[c_employees]--e--[c_size]-3.0.1">1.3.1. Número de colaboradores e dimensao da empresa [c_employees]  e  [c_size]</a></span></li><li><span><a href="#1.3.2.-Idade-das-empresas-:-[c_age]" data-toc-modified-id="1.3.2.-Idade-das-empresas-:-[c_age]-3.0.2">1.3.2. Idade das empresas : [c_age]</a></span></li><li><span><a href="#1.3.3-Tempo-de-Residencia-[c_resident_years]" data-toc-modified-id="1.3.3-Tempo-de-Residencia-[c_resident_years]-3.0.3">1.3.3 Tempo de Residencia [c_resident_years]</a></span></li><li><span><a href="#1.3.4.-Certificação-INAPEM-[c_inapem?]-↥" data-toc-modified-id="1.3.4.-Certificação-INAPEM-[c_inapem?]-↥-3.0.4">1.3.4. Certificação INAPEM [c_inapem?] <a href="#-EMPREENDEDORISMO-EM-ANGOLA">↥</a></a></span></li><li><span><a href="#1.3.5.--Fase-de-incubação--[c_stage]" data-toc-modified-id="1.3.5.--Fase-de-incubação--[c_stage]-3.0.5">1.3.5.  Fase de incubação  [c_stage]</a></span></li><li><span><a href="#1.3.6.-Sectores-de-atividade-[c_act_sector_x]" data-toc-modified-id="1.3.6.-Sectores-de-atividade-[c_act_sector_x]-3.0.6">1.3.6. Sectores de atividade [c_act_sector_x]</a></span></li><li><span><a href="#1.3.7.-Tipos-de-Conhecimento-Transferido-entre-a-Incubadora-e-as-Empresas-[c_knw_trans_]" data-toc-modified-id="1.3.7.-Tipos-de-Conhecimento-Transferido-entre-a-Incubadora-e-as-Empresas-[c_knw_trans_]-3.0.7">1.3.7. Tipos de Conhecimento Transferido entre a Incubadora e as Empresas [c_knw_trans_]</a></span></li><li><span><a href="#1.3.8.-Ferramentas-de-Transferencia-de-Conhecimento-Utilizadas-[c_knw_trans_tool]" data-toc-modified-id="1.3.8.-Ferramentas-de-Transferencia-de-Conhecimento-Utilizadas-[c_knw_trans_tool]-3.0.8">1.3.8. Ferramentas de Transferencia de Conhecimento Utilizadas [c_knw_trans_tool]</a></span></li><li><span><a href="#1.3.8.-Tipos-de-Dificuldades-Encontradas-[c_dif_]" data-toc-modified-id="1.3.8.-Tipos-de-Dificuldades-Encontradas-[c_dif_]-3.0.9">1.3.8. Tipos de Dificuldades Encontradas [c_dif_]</a></span></li><li><span><a href="#1.3.9-Tipos-de-Contributos-mais-Relevantes-Adicionado-pela-Incubadora-[c_inc_value]" data-toc-modified-id="1.3.9-Tipos-de-Contributos-mais-Relevantes-Adicionado-pela-Incubadora-[c_inc_value]-3.0.10">1.3.9 Tipos de Contributos mais Relevantes Adicionado pela Incubadora [c_inc_value]</a></span></li><li><span><a href="#1.3.10.-Tipos-de-Resultados-Obtidos-pela-Incubação-[c_inc_vantagem_]" data-toc-modified-id="1.3.10.-Tipos-de-Resultados-Obtidos-pela-Incubação-[c_inc_vantagem_]-3.0.11">1.3.10. Tipos de Resultados Obtidos pela Incubação [c_inc_vantagem_]</a></span></li></ul></li><li><span><a href="#1.4-Outros-indicadores-relacionados-com-as-Incubadoras" data-toc-modified-id="1.4-Outros-indicadores-relacionados-com-as-Incubadoras-3.1">1.4 Outros indicadores relacionados com as Incubadoras</a></span><ul class="toc-item"><li><span><a href="#1.4.1.-Distribuição-pelas-incubadoras-[inc_name]" data-toc-modified-id="1.4.1.-Distribuição-pelas-incubadoras-[inc_name]-3.1.1">1.4.1. Distribuição pelas incubadoras [inc_name]</a></span></li><li><span><a href="#1.4.2.-Comunicação-da-Incubadora-com-a-Empresa-[c_linkto_inc]" data-toc-modified-id="1.4.2.-Comunicação-da-Incubadora-com-a-Empresa-[c_linkto_inc]-3.1.2">1.4.2. Comunicação da Incubadora com a Empresa [c_linkto_inc]</a></span></li><li><span><a href="#1.4.3.-Ligação-das-Incubadora-a-uma-Universidade-[c_inc_link_uni?]" data-toc-modified-id="1.4.3.-Ligação-das-Incubadora-a-uma-Universidade-[c_inc_link_uni?]-3.1.3">1.4.3. Ligação das Incubadora a uma Universidade [c_inc_link_uni?]</a></span></li><li><span><a href="#1.4.4.-Suporte-das-incubadoras-após-incubação-[c_inc_pos_support?]" data-toc-modified-id="1.4.4.-Suporte-das-incubadoras-após-incubação-[c_inc_pos_support?]-3.1.4">1.4.4. Suporte das incubadoras após incubação [c_inc_pos_support?]</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ---

# %%
#importing modules used for plotting and analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#plt.style.use('ggplot')
import seaborn as sns
sns.set_theme()
#from gapminder import gapminder # import data set 
#pd.set_option('display.max_columns', 60)

# %%
#importing datatypes from the cleaned dataset
import json
with open('./data_output/incubados_dtypes.json', 'r') as j:
    incubados_types = json.load(j)
#importing the clean dataset
survey = pd.read_csv('./data_output/incubados.csv', index_col=0, dtype=incubados_types)

# %% [markdown]
# ## 1. INCUBADOS
# [↥](#-EMPREENDEDORISMO-EM-ANGOLA)

# %% [markdown]
# ## 1.1. CARACTERIZAÇÃO GERAL DA BASE DE DADOS

# %% [markdown]
# Começamos por listar todas as colunas da base de dados, o respectivo nome, numero de registos e respectiva tipologia de dados.

# %%
survey.info() #lista de todas as variáveis e respectivos tipos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64 entries, 1 to 64
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   p_age                          64 non-null     category
#  1   p_gender                       64 non-null     category
#  2   p_literacy                     64 non-null     category
#  3   inc_name                       64 non-null     category
#  4   c_employees                    64 non-null     category
#  5   c_age                          63 non-null     category
#  6   c_inapem?                      63 non-null     boolean
#  7   c_size                         64 non-null     category
#  8   c_resident_years               64 non-null     float64
#  9   c_stage                        64 non-null     category
#  10  c_linkto_inc                   64 non-null     category
#  11  c_inc_link_uni?                59 non-null     boolean
# ...

# %% [markdown]
# A base de dados resultante do tratamento das respostas dos empreendedores tem 64 entradas (correspondendo a cada um dos entrevistados) e 54 colunas, correspondendo às cada uma das perguntas.

# %% [markdown]
# **Os 5 primeiros registos da base de dados:**

# %%
#Sample da base de dados (5 primeiros registos)
survey.head(5)
# Out:
#      p_age   p_gender    p_literacy       inc_name c_employees   c_age  \
# ID
# 1    55-64  Masculino  Licenciatura  CLESE Cabinda    10 - 100  6 - 10
# 2    25-34   Feminino  Licenciatura    CLESE Dundo    10 - 100   1 - 2
# 3    18-24   Feminino  Licenciatura   CLESE Huambo      1 - 10   0 - 1
# 4    25-34  Masculino      Mestrado   CLESE Huambo      1 - 10   3 - 5
# 5    25-34  Masculino  Licenciatura   CLESE Huambo    10 - 100   3 - 5
#
#     c_inapem?   c_size  c_resident_years    c_stage  ... c_inc_value_new_prod  \
# ID                                                   ...
# 1       False  Pequena               1.0  Incubação  ...                False
# 2        True  Pequena               1.0  Incubação  ...                False
# 3       False    Micro               0.5  Incubação  ...                 True
# 4       False    Micro               2.0  Incubação  ...                False
# 5       False  Pequena               3.0  Incubação  ...                False
#
# ...

# %% [markdown]
# ---

# %% [markdown]
# **Heatmap dos Valores Omissos**
#
# A limpeza e tratamento de dados efetuados na
# [Parte 1](./Parte1%20Limpeza%20e%20Tratamento%20de%20Dados.ipynb)
# deste projecto, permitiu eliminar a maior parte de valores omissos, excepto (como se pode ver no heatmap seguinte) um numero significativo de valores nulos na coluna 'c_inc_pos_support?' que corresponde  à pergunta: A incubadora continua a apoiar após a sua saída da incubadora?

# %%
# Mapa de valores omissos 
plt.figure(figsize=(15,5))
sns.heatmap(survey.notnull(), linewidths=1, cbar=False)
plt.xlabel("variáveis")
plt.ylabel("empresas incubadas")
plt.title("Heatmap dos Valores Omissos / Ausência de Respostas")
plt.show()

# %% [markdown]
# **Mapa de Correlações da Base de dados**
# O mapa de correlações abaixo indica uma predominancia ausência de variáveis sem associação, indicando contudo, correlação potencial entre:
# - Ferramentas de transferência de conhecimento e sectores de atividade
# - Entre as opçoes de resposta à mesma pergunta (indicando uma possível redundância nas opções)
# - Entre a pergunta do suporte da incubadora e a sua ligação a uma universidade
# - Entre os resultados

# %%
#Mapa de correlações 
f, ax = plt.subplots(figsize=(15, 10))
sns.heatmap(survey.corr(), annot=False, square=False, linewidths=.5, ax=ax, vmin=.0)
plt.show()

# %% [markdown]
# **Estatísticas Descritivas:**

# %%
survey.describe(include='all')
# Out:
#          p_age   p_gender    p_literacy inc_name c_employees  c_age c_inapem?  \
# count       64         64            64       64          64     63        63
# unique       4          2             3       12           2      5         2
# top      25-34  Masculino  Licenciatura   INAPEM      1 - 10  3 - 5      True
# freq        42         57            40       17          53     30        42
# mean       NaN        NaN           NaN      NaN         NaN    NaN       NaN
# std        NaN        NaN           NaN      NaN         NaN    NaN       NaN
# min        NaN        NaN           NaN      NaN         NaN    NaN       NaN
# 25%        NaN        NaN           NaN      NaN         NaN    NaN       NaN
# 50%        NaN        NaN           NaN      NaN         NaN    NaN       NaN
# 75%        NaN        NaN           NaN      NaN         NaN    NaN       NaN
# max        NaN        NaN           NaN      NaN         NaN    NaN       NaN
#
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### 1.2. DADOS DOS EMPREENDORES
# [↥](#-EMPREENDEDORISMO-EM-ANGOLA)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Existem 3 dados relativos aos empreendedores: Idade, Género e Nível de Escolaridade.
#     O perfil mais frequente é um empreendedor do género masculino, com idade entre os 25 e os 34 anos e possuidor de uma licenciatura.
# </div>

# %%
survey[survey.columns[:3]].describe()
# Out:
#          p_age   p_gender    p_literacy
# count       64         64            64
# unique       4          2             3
# top      25-34  Masculino  Licenciatura
# freq        42         57            40

# %% [markdown]
# #### 1.2.1. Idade [p_age]

# %%
#age
#survey['p_age'].value_counts().plot(kind='bar')
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.countplot(y='p_age', data=survey)
plt.title('Distribuição dos Empreendedores por grupo etário')
plt.ylabel('Grupos Etários')
plt.xlabel('Número de Empreendedores')
#plt.show()

#plt.figure()
plt.subplot(1,2,2)
survey['p_age'].value_counts().plot(kind='pie', autopct='%1.0f%%', pctdistance=0.7)
plt.title('Distribuição dos Empreendedores por grupo etário')
plt.ylabel('')
plt.show()

# %% [markdown]
# #### 1.2.2. Género [p_gender]

# %%
#gender 
#survey['p_gender'].value_counts().plot(kind='bar')
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.countplot(x='p_gender', data=survey, order=['Masculino','Feminino'])
plt.title('Distribuição dos Empreendedores por Genero')
plt.ylabel('Géneros')
plt.xlabel('Número de Empreendedores')

plt.subplot(1,2,2)
survey['p_gender'].value_counts().plot(kind='pie', autopct='%1.0f%%', pctdistance=0.7)
plt.title('Distribuição dos Empreendedores por Género')
plt.ylabel('')
plt.show()

# %% [markdown]
# A grande maioria dos empreendedores é do genero masculino.

# %% [markdown]
# #### 1.2.3. Nível de Escolaridade [p_literacy]

# %%
#literacy
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.countplot(x='p_literacy', data=survey)
plt.title('Frequencia do Nível de escolaridade')
plt.xlabel('Nível Escolaridade')
plt.xticks(rotation=0)
plt.ylabel('Frequência')

plt.subplot(1,2,2)
survey['p_literacy'].value_counts().plot(kind='pie',autopct='%1.0f%%', pctdistance=0.7)
plt.title('Distribuição dos Empreendedores por Nivel de Escolaridade')
plt.ylabel('')
plt.show()

# %%
#distribuição de idades por nivel de escolaridade
plt.figure(figsize=(15,5))
sns.countplot(x='p_literacy', hue='p_age', data=survey)
plt.title('Frequencia de Idades por Nível de Escolaridade')
plt.xlabel('Nível de Escolaridade')
plt.ylabel('Frequência')
plt.legend()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Mais de metade dos empreendedores têm licenciatura e uma idade entre os 25 e 34 anos. Apenas 4 empreendedores têm mestrado. A maior parte dos empreendedores mais jovens completaram apenas o nível tecnico médio.
# </div>

# %%
survey['p_literacy'].value_counts()
# Out:
# Licenciatura     40
# Técnico Médio    20
# Mestrado          4
# Name: p_literacy, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ## 1.3 CARACTERIZAÇÃO DAS EMPRESAS INCUBADAS
# [↥](#-EMPREENDEDORISMO-EM-ANGOLA)
#
# Considerando o elavado numero de varáveis, vamos "partir" a análise em seçoes. Esta primeira seção caracteriza a amostra de empresas incubadas em relação aop número de colaboradores, idade, certificaçao inapem,  dimensão, tempo de residencia na incubadora e estágio de incubação.
#
#
# |Index|Coluna / Variável         |Tipo |Interesse|
# |:-:|:---------------------------|:----|:-------:|
# |4 |c_employees                  | categorica|[x]|
# |5 |c_age                        | categorica|[x]|
# |6|c_inapem?                    | bool|[x]|
# |7|c_size                       | categorica|[x]|
# |8|c_resident_years             | float|[x]|
# |9|c_stage                      | categorica|[x]|

# %% [markdown]
# #### 1.3.1. Número de colaboradores e dimensao da empresa [c_employees]  e  [c_size]

# %%
#colaboradores - 'c_employees'
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.countplot(x='c_employees' ,data=survey)
plt.title('Frequência do Número de Colaboradores')
plt.xlabel('Número de colaboradores')
plt.xticks(rotation=0)
plt.ylabel('Frequência')

plt.subplot(1,2,2)
sns.countplot(x='c_size' ,data=survey)
plt.title('Frequência das empresas por Dimensão')
plt.xlabel('Dimensão da Empresa')
plt.xticks(rotation=0)
plt.ylabel('Frequência')

plt.show()

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
survey['c_employees'].value_counts().plot(kind='pie',autopct='%1.0f%%', pctdistance=0.7)
plt.title('Frequência do Número de Colaboradores')
plt.ylabel('')

plt.subplot(1,2,2)
survey['c_size'].value_counts().plot(kind='pie',autopct='%1.0f%%', pctdistance=0.7)
plt.title('Dimensão da Empresa')
plt.ylabel('')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
#     A grande maioria das empresas incubadas apresenta uma dimensão típica de start-up com um número de colaboradores inferiores a 10, contudo 30% das empresas incubadas revela ter uma dimensão de pequena empresa o que sugere um crescimento das empresas incubadas.
# </div>

# %% [markdown]
# #### 1.3.2. Idade das empresas : [c_age]

# %%
survey['c_age'].describe()
# Out:
# count        63
# unique        5
# top       3 - 5
# freq         30
# Name: c_age, dtype: object

# %%
#company age 
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.countplot(x='c_age' ,data=survey)
plt.title('Frequência das empresas por Idade')
plt.xlabel('Grupos de Idade das empresas')
plt.xticks(rotation=0)
plt.ylabel('Frequência')

plt.subplot(1,2,2)
survey['c_age'].value_counts().plot(kind='pie',autopct='%1.0f%%', pctdistance=0.7)
plt.title('Frequência das empresas por Idade')
plt.ylabel('')
plt.show()

# %% [markdown]
# #### 1.3.3 Tempo de Residencia [c_resident_years]

# %%
survey['c_resident_years'].median() #calcula o tempo de residencia com maior frequencia
# Out:
# 1.0

# %%
survey['c_resident_years'].describe()
# Out:
# count    64.000000
# mean      1.585938
# std       1.226541
# min       0.500000
# 25%       0.500000
# 50%       1.000000
# 75%       3.000000
# max       4.000000
# Name: c_resident_years, dtype: float64

# %%
#resident years
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
sns.countplot(x='c_resident_years', data=survey)
plt.title('Frequência das empresas por tempo de residência na incubadora')
plt.xlabel('Tempo de residência')
plt.xticks(rotation=0)
plt.ylabel('Frequência')

plt.subplot(1,2,2)
survey['c_resident_years'].value_counts().plot(kind='pie',autopct='%1.0f%%', pctdistance=0.7)
plt.title('Tempo de residência')
plt.ylabel('')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# Sendo a unica variável númerica (convertida durante o tratamento), é possivel determinar um conjunto de estatisticas simples: (total de observaçoes, média, desvio padrão, minimo, Percentil 25, 50 e 75 e máximo.
# Verifica-se assim que as empresas inquiridas estão incubadas em média há 1,5 anos, sendo que a maioria está na incubadora há menos de seis meses.
# </div>

# %% [markdown]
# #### 1.3.4. Certificação INAPEM [c_inapem?] [↥](#-EMPREENDEDORISMO-EM-ANGOLA)

# %%
survey['c_inapem?'].value_counts(dropna=False)
# Out:
# True     42
# False    21
# NaN       1
# Name: c_inapem?, dtype: Int64

# %%
mylabels = ["Com", "Sem", "Não Responde"]
survey['c_inapem?'].value_counts(dropna=False).plot(kind='pie',autopct='%1.0f%%', pctdistance=0.7, labels=mylabels)
plt.title('Certificação INAPEM')
plt.ylabel('')
plt.show()

# %% [markdown]
# A maior parte das empresas tem certificaçao INAPEM

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
sns.countplot(x='c_age', hue='c_size',data=survey)
plt.title('Dimensao das Empresas por Grupos de Idade')
plt.xlabel("Idade da Empresa")
plt.ylabel("Numero de Empresas")

plt.subplot(1,2,2)
sns.countplot(data=survey, x='c_resident_years', hue='c_size')
plt.title('Dimensao das Empresas por Tempo de Residência na Incubadora')
plt.xlabel("Tempo das Empresas na Incubadora (Residência)")
plt.ylabel("Numero de Empresas")

plt.show()

# %% [markdown]
# Cálculo da correlação (de Pearson) entre o tempo de residencia e a dimensão da empresa

# %%
#cria uma novacoluna onde os valores de dimensao sao numéricos para permitir correlação
replace_keys = {'Micro':0, 'Pequena':1}
survey['c_size_coded']=survey['c_size'].replace(replace_keys)
survey.corr()['c_resident_years']['c_size_coded']
# Out:
# -0.09036999184921993

# %% [markdown]
# <div class="alert alert-block alert-info">
# Verifica-se uma maior frequência de empresas com idade entre os 3 e 5 anos de idade com uma dimensão de micro. O número de empresas com mais de 5 anos é reduzida indicando um possível threeshold the mortalidade ou saída da incubadora (corroborado pelo tempo de residência médio de 1,5 anos). Não foi encontrada uma correlação significativa entre o tempo de residência e a dimensão da empresa, ou seja não é possível determinar se o tempo que a empresa passa na incubadora a ajuda a crescer em dimensão.
# </div>

# %% [markdown]
# #### 1.3.5.  Fase de incubação  [c_stage]
# A maior parte das empresas encontram-se em fase de incubação.

# %%
survey['c_stage' ].value_counts()
# Out:
# Incubação          41
# Pré - Incubação    17
# Pós - Incubação     5
# Graduação           1
# Name: c_stage, dtype: int64

# %%
#estágio de incubação
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.countplot(x='c_stage', data=survey, order=['Graduação','Pré - Incubação','Incubação','Pós - Incubação'])
plt.title('Frequência das empresas por Fase de Incubação')
plt.xlabel('Fases de Incubação')
plt.xticks(rotation=0)
plt.ylabel('Frequência')

plt.subplot(1,2,2)
survey['c_stage'].value_counts().plot(kind='pie',autopct='%1.0f%%', pctdistance=0.7)
plt.title('Percentagem de empresas em cada Fase de Incubação')
plt.ylabel('')
plt.show()

# %% [markdown]
# Abaixo a relação entre o tempo em que a empresa está na incubadora, e o seu estágio de incubação.

# %%
#relaçao entre estagio de incubaçao e tempo na incubadora
plt.figure(figsize=(15,5))
sns.set_theme()
order=["Graduação", "Pré - Incubação", "Incubação","Pós - Incubação"]
sns.stripplot(data=survey, x='c_stage',y='c_resident_years', order=order, hue='c_age', s=10)
plt.title('Distribuição do Tempo de incubação por Fase de Incubação')
plt.xlabel('Fase de Incubação')
plt.xticks(rotation=0)
plt.ylabel('Tempo de Residência na Incubadora')

plt.show()

# %% [markdown]
# **Sumário da análise até este momento:**

# %% [markdown]
# <div class="alert alert-block alert-info">
#     A caracterização das empresa incubadas até ao momento revela uma empresa de dimensão micro, com menos de 10 empregados, criada ha menos de 5 anos e mais de 3, em fase incubação há menos de 6 meses. A maior parte das empresas tem certificação INAPEM
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# ⏭ Sugestão para investigação futura: Distinguir entre empresas currentemente incubadas e que já sairam das incubadoras, assim como adquirir dados pós- incubação (para permitir relacionar com outras variáveis de desempenho).
# </div>

# %% [markdown]
# ---

# %% [markdown]
# #### 1.3.6. Sectores de atividade [c_act_sector_x]
#
# |Index|Coluna / Variável         |Tipo |Descrição|
# |:-:|:---------------------------|:----|:------------------------------------------------------------|
# |13|c_act_sector_O               | bool|Outras Actividades de Serviços Colectivos, Social e Pessoais|
# |14|c_act_sector_K               | bool|Actividades Imobiliárias, Alugueres e Serviços Prestados às Empresas|
# |15|c_act_sector_H               | bool|Alojamento e Restauração (Restaurantes e Similares)|
# |16|c_act_sector_M               | bool|Educação|
# |17|c_act_sector_A               | bool|Agricultura, Produção Animal e Silvicultura|
# |18|c_act_sector_C               | bool|Indústrias Extractivas|
# |19|c_act_sector_F               | bool|Construção e obras públicas|
# |20|c_act_sector_J               | bool|Actividades Financeiras|
# |21|c_act_sector_E               | bool|Produção e distribuição de Electricidade, Gás e de Água|
# |22|c_act_sector_G               | bool|Comércio por Grosso e a Retalho; Reparação de Veículos Automóveis, Motociclos e de Bens de Uso Pessoal e Doméstico|
# |23|c_act_sector_I               | bool|Transportes, Armazenagem e Comunicações|
# |24|c_act_sector_N               | bool|Saúde e Acção Social|

# %% [markdown]
# Total de empresas em cada sector

# %%
data = survey.iloc[:,13:25].sum().sort_values(ascending=False)
data
# Out:
# c_act_sector_O    34
# c_act_sector_K    11
# c_act_sector_G     8
# c_act_sector_M     6
# c_act_sector_H     5
# c_act_sector_F     5
# c_act_sector_A     4
# c_act_sector_J     2
# c_act_sector_C     1
# c_act_sector_E     1
# c_act_sector_I     1
# c_act_sector_N     1
# dtype: int64

# %%
#sector de atividade
sectores = ['(O)- Outras Actividades de Serviços Colectivos, Social e Pessoais',
            '(K)- Actividades Imobiliárias, Alugueres e Serviços Prestados às Empresas',
            '(G)- Comércio por Grosso e a Retalho; Reparação de Veículos Automóvel, Motociclos e de Bens de Uso Pessoal e Doméstico',
            '(M)- Educação',
            '(H)- Alojamento e Restauração (Restaurantes e Similares)',
            '(F)- Construção e obras públicas',
            '(A)- Agricultura, Produção Animal e Silvicultura',
            '(J)- Actividades Financeiras',
            '(C)- Indústrias Extractivas',
            '(E)- Produção e distribuição de Electricidade, Gás e de Água',
            '(I)- Transportes, Armazenagem e Comunicações',
            '(N)- Saúde e Acção Social']

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
data.sort_values().plot(kind='barh')
#plt.yticks(np.arange(12), sectores, rotation=0)  # Set text labels.
plt.title('Frequência das empresas por Sector de Atividade')
plt.xlabel('Número de empresas')
plt.ylabel('Sector de Atividade')


plt.subplot(1,2,2)
data.plot(kind='pie',autopct='%1.0f%%', pctdistance=0.7)
plt.ylabel('')
plt.title('Frequência das empresas por Sector de Atividade')


plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# O sector mais frequente é o de 'Outras Actividades de Serviços Colectivos, Social e Pessoais', representando mais de 40% das empresas incubadas.
#     </div>

# %% [markdown]
# #### 1.3.7. Tipos de Conhecimento Transferido entre a Incubadora e as Empresas [c_knw_trans_]
#
# |Index|Coluna / Variável         |Tipo |Descrição|
# |:-:|:---------------------------|:----|:-----------|
# |25|c_knw_trans_mrkt             | bool|[Marketing]|
# |26|c_knw_trans_hr               | bool|[Recursos Humanos]|
# |27|c_knw_trans_sales            | bool|[Comercialização de produtos e serviços]|
# |28|c_knw_trans_legal            | bool|[Assistência jurídica]|
# |29|c_knw_trans_entrpre          | bool|[Empreendedorismo]|
# |30|c_knw_trans_strt             | bool|[Gestão Estratégica]|
# |31|c_knw_trans_finc             | bool|[Gestão Financeira]|

# %% [markdown]
# Totais dos tipologias de conhecimento

# %%
known = survey[survey.columns[25:32]]
known.sum().sort_values(ascending=False)
# Out:
# c_knw_trans_entrpre    29
# c_knw_trans_mrkt       18
# c_knw_trans_hr         16
# c_knw_trans_sales      13
# c_knw_trans_finc        9
# c_knw_trans_legal       6
# c_knw_trans_strt        2
# dtype: int64

# %%
#tipologias de conhecimento transferid
#labels = ['Marketing', 'Recursos Humanos','Comercialização de produtos e serviços','Assistência jurídica','Empreendedorismo', 'Gestão Estratégica', 'Gestão Financeira']
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
known.sum().sort_values().plot(kind='barh')
#plt.yticks(np.arange(12), sectores, rotation=0)  # Set text labels.
plt.title('Frequência de Tipo de Conhecimento Transferido')
plt.xlabel('Número de empresas')
plt.ylabel('Tipo de Conhecimento Transferido')

plt.subplot(1,2,2)
known.sum().plot(kind='pie',autopct='%1.0f%%', pctdistance=0.7)
plt.ylabel('')
plt.title('Frequência de Tipo de Conhecimento Transferido')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# A maior parte dos conhecimento transmitidos das incubadoras para as empresas estão relacionados com noções de empreendedorismo seguidos de conhecimentos de marketing.
#     </div>

# %% [markdown]
# #### 1.3.8. Ferramentas de Transferencia de Conhecimento Utilizadas [c_knw_trans_tool]
# |Index|Coluna / Variável         |Tipo |Descrição|
# |:-:|:---------------------------|:----|:-----------|
# |32|  c_knw_trans_tool_manuais|bool|[Manuais]|
# |33|c_knw_trans_tool_training    | bool|[Formação e cursos]|
# |34|c_knw_trans_tool_benchmarking| bool|[Benchmarking]|
# |35|c_knw_trans_tool_forums      | bool|[Fórums]|

# %%
tools = survey[survey.columns[32:36]]
tools.sum().sort_values(ascending=False)
# Out:
# c_knw_trans_tool_training        46
# c_knw_trans_tool_manuais         26
# c_knw_trans_tool_forums           5
# c_knw_trans_tool_benchmarking     3
# dtype: int64

# %%
#tipologias de ferraments de transferencia
labels = ['Benchmarking','Fórums','Manuais','Formação e cursos']

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
tools.sum().sort_values().plot(kind='barh')
plt.yticks(np.arange(4), labels, rotation=0)  # Set text labels.
plt.title('Frequência da Utilização de Ferramentas de Transferência de Conhecimento')
plt.xlabel('Frequência')
plt.ylabel('Ferramentas de Transferência de Conhecimento')

plt.subplot(1,2,2)
tools.sum().sort_values().plot(kind='pie',autopct='%1.0f%%', pctdistance=0.7, labels=labels)
plt.ylabel('')
plt.title('Frequência da Utilização de Ferramentas de Transferência de Conhecimento')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# A maior parte dos conhecimento transmitidos das incubadoras para as empresas estão relacionados com noções de empreendedorismo seguidos de conhecimentos de marketing.
#     </div>

# %% [markdown]
# #### 1.3.8. Tipos de Dificuldades Encontradas [c_dif_]
#
# |Index|Coluna / Variável         |Tipo |Descrição|
# |:-:|:---------------------------|:----|:-----------|
# |36 | c_dif_funds                |bool| ['Acesso a financiamentos e investimentos]|
# |37 | c_dif_bplan                |bool| [Ausência de conhecimento técnico e tecnológico para elaboração do Plano de negócios]|
# |38 | c_dif_place                |bool| [Ausência de Infra-estruturas Físicas]|
# |39 | c_dif_manag_xp             |bool| [Ausência ou baixa experiência em gestão empresarial]|
# |40 | c_dif_skills               |bool| [Baixa qualificação dos funcionários]|
# |41 | c_dif_entrep               |bool| [Pouca ou nenhuma noção sobre empreendedorismo]|

# %% [markdown]
# Totais das dificuldades identificadas pelos empreendedores

# %%
dif = survey[survey.columns[36:42]]
dif.sum()
# Out:
# c_dif_funds       51
# c_dif_bplan        9
# c_dif_place       11
# c_dif_manag_xp     6
# c_dif_skills       5
# c_dif_entrep       1
# dtype: int64

# %%
#tipologias de difculdes - grafico
labels = [
    'Acesso a financiamentos e investimentos ',
    'Ausência de conhecimento técnico e tecnológico para elaboração do Plano de negócios ',
    'Ausência de Infra-estruturas Físicas ',
    'Ausência ou baixa experiência em gestão empresarial  ',
    'Baixa qualificação dos funcionários ',
    'Pouca ou nenhuma noção sobre empreendedorismo ',
    ]
labels.reverse()

dif.sum().sort_values().plot(kind='barh')
plt.yticks(np.arange(6), labels, rotation=0)  # Set text labels.
plt.title('Frequência das dificuldades sentidas pelos empreendedores')
plt.xlabel('Frequência')
plt.ylabel('Dificuldades')
plt.show()


dif.sum().sort_values().plot(kind='pie',autopct='%1.0f%%', pctdistance=0.7, labels=labels)
plt.ylabel('')
plt.title('Frequência das dificuldades sentidas pelos empreendedores')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# A maior dificuldade sentida relaciona-se com a dificuldade de acesso a financiamento e investimento.
#     </div>

# %% [markdown]
# #### 1.3.9 Tipos de Contributos mais Relevantes Adicionado pela Incubadora [c_inc_value]
#
# |Index|Coluna / Variável         |Tipo |Descrição|
# |:-:|:---------------------------|:----|:-------|
# |42 | c_inc_value_manag_tools    | bool|[Ferramentas de gestão]|
# | 43|  c_inc_value_tek_res       | bool|[Recursos Tecnológicos]|
# | 44|  c_inc_value_new_prod      | bool|[Desenvolvimento de novos produtos]|
# | 45|  c_inc_value_network       | bool|[Acesso a redes de empresas já incubadas]|
# | 46|  c_inc_value_markt         | bool|[Desenvolvimento do Marketing]|
# | 47|  c_inc_value_divisas       | bool|[Obtenção de Divisas] |
# | 48|  c_inc_value_credit        | bool|[Acesso ao Crédito]|

# %% [markdown]
# Totais de contributos adicionados

# %%
value = survey[survey.columns[42:49]].sum()
value.sort_values(ascending=False)
# Out:
# c_inc_value_network        22
# c_inc_value_tek_res        16
# c_inc_value_manag_tools    15
# c_inc_value_markt          14
# c_inc_value_new_prod        8
# c_inc_value_credit          4
# c_inc_value_divisas         3
# dtype: int64

# %%
#tipologias de difculdes - grafico
labels = [
    'Acesso a redes de empresas já incubadas',
    'Recursos Tecnológicos',
    'Ferramentas de gestão',
    'Desenvolvimento do Marketing', 
    'Desenvolvimento de novos produtos',
    'Acesso ao Crédito',
    'Obtenção de Divisas ']

labels.reverse()

plt.figure(figsize=(15,5), dpi=400)

plt.subplot(1,2,1)
value.sort_values().plot(kind='barh')
plt.yticks(np.arange(7), labels, rotation=0)  # Set text labels.
plt.title('Vantagens Sentidas Durante a Incubação')
plt.xlabel('Frequência')
plt.ylabel('Vantagens')

plt.subplot(1,2,2)
value.sort_values().plot(kind='pie',autopct='%1.0f%%', pctdistance=0.7, labels=labels)
plt.ylabel('')
plt.title('Vantagens Sentidas Durante a Incubação')

plt.show()

# %%
survey[survey.columns[42:49]].mean() * 100 #percentagem de respostas positivas para cada opção
# Out:
# c_inc_value_manag_tools    23.4375
# c_inc_value_tek_res        25.0000
# c_inc_value_new_prod       12.5000
# c_inc_value_network        34.3750
# c_inc_value_markt          21.8750
# c_inc_value_divisas         4.6875
# c_inc_value_credit          6.2500
# dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-info">
# O maior contributo identificado pelos empreendedores relaciona-se com o acesso a outras empresas incubadas. Contudo as respostas indicam que nenhuma das opções é assinalada por mais de 35%.
#     </div>

# %% [markdown]
# #### 1.3.10. Tipos de Resultados Obtidos pela Incubação [c_inc_vantagem_]
#
# |Index|Coluna / Variável         |Tipo |Descrição|
# |:-:|:---------------------------|:----|:-------|
# |49 | c_inc_vantagem_network_oport |bool|[Rede de contactos para oportunidades de negócio]|
# |50 | c_inc_vantagem_senior_partn  |bool|[Parcerias com empresas já firmadas no mercado]|
# |51 | c_inc_vantagem_image         |bool|[A grande visibilidade que a Incubadora proporciona a Empresa]|
# |52 | c_inc_vantagem_rent          |bool|[Não pagar a renda de um escritório]|
# |53 | c_inc_vantagem_wifi          |bool|[Internet banda larga 24/24]|

# %%
result = survey[survey.columns[49:54]].sum()
result.sort_values(ascending=False)
# Out:
# c_inc_vantagem_network_oport    30
# c_inc_vantagem_image            27
# c_inc_vantagem_rent             15
# c_inc_vantagem_senior_partn     13
# c_inc_vantagem_wifi             13
# dtype: int64

# %%
#tipologias de vantagens mais significatiovos
labels = ['Contactos p/ oportunidades de negócio',
          'Visibilidade',
          'Não pagar a renda de um escritório',
          'Parcerias com empresas no mercado',
          'Internet banda larga 24/24']

labels.reverse()

plt.figure(figsize=(15,5), dpi=300)

plt.subplot(1,2,1)
result.sort_values().plot(kind='barh')
plt.yticks(np.arange(5), labels, rotation=0)  # Set text labels.
plt.title('Frequência das dificuldades sentidas pelos empreendedores')
plt.xlabel('Frequência')
plt.ylabel('Dificuldades')

plt.subplot(1,2,2)
result.sort_values().plot(kind='pie',autopct='%1.0f%%', pctdistance=0.7, labels=labels)
plt.ylabel('')
plt.title('Frequência das dificuldades sentidas pelos empreendedores')

plt.show()

# %%
survey.corr()['c_inc_vantagem_rent']['c_inc_vantagem_wifi'] #encontra o valor do factor de correlação de pearson entre os dois factores
# Out:
# 0.5457887026765409

# %% [markdown]
# <div class="alert alert-block alert-info">
# As maiores vantagens relacionam-se com as oportunidades de negócio geradas pelas incubadora (cerca de metade dos empreendedores indentificaram as oportunidades de negocio como uma vantagem de estar incubados). A correlação sugerida no grafico inicial confirma-se num valor de r=0.55 o que indica uma associação positiva entre os empreendedores que identificam a vantagem de não pagar a renda com o beneficio de obter acesso a banda larga.
#     </div>

# %% [markdown]
# ### 1.4 Outros indicadores relacionados com as Incubadoras
# [↥](#-EMPREENDEDORISMO-EM-ANGOLA)
#
# |Index|Coluna / Variável         |Tipo |Interesse|
# |:-:|:---------------------------|:----|:-------:|
# |3 |  inc_name                  | category|[Nome da Incubadora]|
# |10|c_linkto_inc                 | category|[Avaliação da comunicaçao com a incubadora]|
# |11|c_inc_link_uni?              | bool|[Ligaçao da incubadora a uma universidade]|
# |12|c_inc_pos_support?           | bool|[Continuidade do suporte da incubadora, após a incubação]|

# %% [markdown]
# #### 1.4.1. Distribuição pelas incubadoras [inc_name]

# %% [markdown]
# Total de empresas incubadas em cada incubadora

# %%
survey['inc_name'].value_counts()
# Out:
# INAPEM                17
# CLESE Uíge            11
# CLESE Huambo          10
# CLESE Huíla            9
# CLESE Malange          5
# CLESE Sumbe            4
# CLESE Kuanza Norte     3
# CLESE Benguela         1
# CLESE Cabinda          1
# CLESE Dundo            1
# CLESE Moxico           1
# IEMP                   1
# Name: inc_name, dtype: int64

# %%
replace_keys = {False:'Não', True:'Sim'}
survey['c_inapem?']=survey['c_inapem?'].replace(replace_keys).fillna('Sem Resposta')


survey['c_size_coded']=survey['c_size'].replace(replace_keys)

survey['inc_name'].value_counts(dropna=True).sort_values().plot(kind='barh')
plt.title('Número de Empresas em cada Incubadora')
plt.xlabel("Número de Empresas")
plt.show()

sns.countplot(data=survey, y='inc_name', hue='c_inapem?')


plt.legend(title='Certificação INAPEM', loc='upper right', labels=['Não','Sim'])
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# A incubadora INAPEM reune o maior número de empresas incubadas. Apenas duas empresas na INAPEM não possuem certificação. No resto das incubadoras, apenas a CLESE do Huambo tem mais empresa sem certificado do que com.
#     </div>

# %%
#### 1.4.2. Qualidade e Frequência da comunicação das incubadoras com as empresas

# %% [markdown]
# #### 1.4.2. Comunicação da Incubadora com a Empresa [c_linkto_inc]

# %%
plt.figure(figsize=(5,5)) 
survey['c_linkto_inc'].value_counts(dropna=True).sort_values().plot(kind='pie',autopct='%1.0f%%', pctdistance=0.7)
plt.title('Qualidade e Frequência da Comunicação entre Incubadoras e Empresas')
plt.ylabel('')
plt.show()

# %% [markdown]
# #### 1.4.3. Ligação das Incubadora a uma Universidade [c_inc_link_uni?]

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
uni = survey['c_inc_link_uni?'].value_counts()
uni.plot(kind='pie',autopct='%1.0f%%', pctdistance=0.7, labels=['Não','Sim'])
plt.title('Percentagem de Empresas com Ligação a uma Universidade')
plt.ylabel('')

survey['c_inc_link_uni?'] = survey['c_inc_link_uni?'].fillna(False)

plt.subplot(1,2,2)
sns.countplot(data=survey,y='inc_name', hue='c_inc_link_uni?')
plt.ylabel('')
plt.xlabel('Número de Empresas')
plt.legend(title='Ligação à Universidade', loc='upper right', labels=['Não','Sim'])
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# A maior parte das incubadoras não possui uma ligação a uma universidade, segundo as respostas dos empreendedores. As CLESES de Huila e Uige, são as mais empreendedores consideram que possuem uma ligação a uma universidade.
#     </div>

# %% [markdown]
# #### 1.4.4. Suporte das incubadoras após incubação [c_inc_pos_support?]

# %%
support = survey['c_inc_pos_support?'].value_counts()
support
# Out:
# False    30
# True     19
# Name: c_inc_pos_support?, dtype: Int64

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
support.plot(kind='pie',autopct='%1.0f%%', pctdistance=0.7, labels=['Não','Sim'])
plt.title('Percentagem de Empresas com Ligação a uma Universidade')
plt.ylabel('')

survey['c_inc_pos_support?'] = survey['c_inc_pos_support?'].fillna(False)

plt.subplot(1,2,2)
sns.countplot(data=survey,y='inc_name', hue='c_inc_pos_support?')
plt.ylabel('')
plt.xlabel('Número de Empresas')
plt.legend(title='Suporte Após Saida da Incubadora', loc='upper right', labels=['Não','Sim'])
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# A maior parte dos empreendedores não responde positivamente, sendo nenhum empreendedor considera que o INAPEM oferece suporte após a incubação. Contudo a CLESE de Uige demonstra uma maior percentagem de empreendedores que reconhecem que existe apoio após a incubação.
#     </div>

# %% [markdown]
# [↥](#-EMPREENDEDORISMO-EM-ANGOLA)
